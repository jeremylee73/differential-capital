# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Pipeline psuedo code
#     n = look back window
#     k = number of PCs to keep
#
#     for each time point t:
#         p = number of stocks in investable universe at time t
#         Define an n x p feature matrix X (lagged returns)
#
#         Perform PCA on X
#         Keep the first k PCs in an n x k matrix Z
#
#     for each stock s in the investable universe at time t:
#         Define an n x 1 outcome vector y (future returns of stock s)
#         Perform a linear regression of y on Z
#         Predict y for stock s at time t+1

# %% [markdown]
# ## Data Preparation

# %%
returns_monthly = pd.read_pickle("./Data/returns-monthly.pkl")
returns_monthly
# Out:
#               905270    921795    904261    905261    916328    923024  \
# date
# 1990-01-31 -0.034290 -0.505618 -0.208625 -0.814073 -0.293528 -0.315632
# 1990-02-28  0.455169  0.650143 -0.205743  0.109907 -0.067332 -0.032033
# 1990-03-31  0.355809  0.311451  0.285771  0.256536  0.117143 -0.215774
# 1990-04-30 -0.243626 -0.159577 -0.878102 -0.222391  0.080013 -0.239431
# 1990-05-31  0.185911  0.112843  0.401598  0.335875  0.525889 -0.041198
# ...              ...       ...       ...       ...       ...       ...
# 2021-01-31       NaN       NaN       NaN       NaN  0.653127       NaN
# 2021-02-28       NaN       NaN       NaN       NaN -0.156176       NaN
# 2021-03-31       NaN       NaN       NaN       NaN  0.012640       NaN
# 2021-04-30       NaN       NaN       NaN       NaN  0.016855       NaN
# 2021-05-31       NaN       NaN       NaN       NaN -0.140733       NaN
#
#               936365    902355    912215    929813  ...    9660J1    69568X  \
# date                                                ...
# 1990-01-31 -0.576403  0.010648 -0.693910 -0.338995  ...       NaN       NaN
# 1990-02-28  0.729168  0.595178  0.004846  0.410031  ...       NaN       NaN
# 1990-03-31  0.502729  0.055353  0.005520 -0.354091  ...       NaN       NaN
# 1990-04-30 -0.188944 -0.199850 -0.395150 -0.243304  ...       NaN       NaN
# 1990-05-31  0.863260  0.439779  0.595637  1.106905  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-01-31 -0.324973       NaN       NaN       NaN  ... -0.133998  0.695155
# 2021-02-28 -0.042147       NaN       NaN       NaN  ... -0.152440 -0.772888
# 2021-03-31 -0.276290       NaN       NaN       NaN  ... -0.143479  0.102567
# 2021-04-30  0.220679       NaN       NaN       NaN  ...  0.174703  0.340445
# 2021-05-31 -0.078735       NaN       NaN       NaN  ...  0.579004 -0.591224
#
#               543755    77463M    29235J    131745    69487D    68157P  \
# date
# 1990-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-01-31 -0.045443  0.353482 -0.110210  1.086909  0.075012  0.472987
# 2021-02-28  0.640719 -0.079415  0.325228  0.690940  0.722464  1.635837
# 2021-03-31  0.241327 -0.171112 -0.168559 -0.279081  0.512621  0.035363
# 2021-04-30  0.266917 -0.602222  0.130372 -0.735603 -0.190740 -0.018397
# 2021-05-31 -0.236979  0.200170 -0.220422 -0.345549  0.491805  0.106957
#
#               9110RA    292703
# date
# 1990-01-31       NaN       NaN
# 1990-02-28       NaN       NaN
# 1990-03-31       NaN       NaN
# 1990-04-30       NaN       NaN
# 1990-05-31       NaN       NaN
# ...              ...       ...
# 2021-01-31 -0.196218  0.215045
# 2021-02-28  1.562436  0.545335
# 2021-03-31 -0.232262  0.073939
# 2021-04-30  0.566389  0.663149
# 2021-05-31  0.530459  0.100455
#
# [377 rows x 1237 columns]

# %%
returns = pd.read_pickle("./Data/returns.pkl")
returns = returns.iloc[1:]

# %%
drop_columns = []

for col in returns.columns:
    if returns[col].isnull().all() == True:
        drop_columns.append(col)
        
returns.drop(columns=drop_columns, inplace=True)

# %% [markdown]
# ## Pipeline

# %%
def get_investable(t, n):
    """"Find stocks in investable universe at time t
    (stocks in the S&P500 that have prices recorded for the last n days)"""
    
    df_investable = returns.copy(deep = True).sort_index(ascending = False)
    
    #add 1 date to get the test features in investable
    t = t + pd.DateOffset(1)
    n += 1
    
    #if t is now a non-trading day, advance until we reach a valid trading day
    while t not in df_investable.index:
        t = t + pd.DateOffset(1)
    
    t_index = df_investable.index.get_loc(t)
    
    #take n_rows worth of data upto time specified
    df_investable = df_investable.iloc[t_index:t_index + n]
    
    #find all stocks that exist in the S&P at this time period
    investable_universe = []
    for col in df_investable.columns:
        if ~df_investable[col].iloc[:n].isna().any():
            investable_universe.append(col)
        
    df_investable = df_investable[investable_universe]
    
    return df_investable

# %%
def apply_PCA(inv, k):
    X = inv.iloc[1:, :]
    pca = PCA(n_components = k) 
    inv_scaled = StandardScaler().fit_transform(X)   
    principal_components = pca.fit_transform(inv_scaled)

    df = pd.DataFrame(data = principal_components)
    
    #For explained variance table
    components = pca.components_
    component_explained_var = pca.explained_variance_ratio_ * 100
    
    comp_names = ['PCA' + str(i) for i in range(1, len(component_explained_var) + 1)]

    pca_results = pd.DataFrame(data = component_explained_var, index = comp_names)
    pca_results.columns = ['Explained variance (%)']
    pca_results['Explained variance (%)'] = pca_results['Explained variance (%)'].round(2)
    
    return df

# %%
def define_y(inv, stock, n):
    y = inv[[stock]].iloc[:-1]
    
    return y

# %%
def train_test(X, y):
    X_train = X.iloc[1:, :]
    X_test = X.iloc[0:1, :]
    y_train = y.iloc[1:]
    y_test = y.iloc[0:1]
    
    return X_train, y_train, X_test, y_test

# %%
# Converts investable dataframe into 3D tensor for input into RNN fitting
# Eg. if investable_df has shape (52, 635), it is converted to a numpy array of shape (52, 1, 635)

def formatX(investable_df):
    train_values = []
    # Iterates through each day in investable df and appends feature values to train_values
    for i in range(len(investable_df.index)):
        train_values.append(investable_df.iloc[i].values)
    train_values = np.array(train_values) # converts to numpy array
    train_values = np.reshape(train_values, (train_values.shape[0], 1, train_values.shape[1])) # reshapes to 3-dimensional
    return train_values

# %%
# Formats output for a stock as a np array
# Takes in a stock, a date, and a number of rows to look back on and formats the output values as a numpy array
# Eg. formatY(stockX, Feb.25, 80) outputs the returns for stockX starting from 80 days before Feb.25 up to Feb.25

def formatY(y):
    return np.array(y)[:, 0]

# %%
from keras.callbacks import EarlyStopping

def model_fit(X_train, y_train):
    
    convertedX = formatX(X_train)
    convertedY = formatY(y_train)
    
    model = Sequential()
    model.add(LSTM(units=32, input_shape=(convertedX.shape[1], convertedX.shape[2]), activation="relu"))
    model.add(Dense(8, activation="relu"))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='rmsprop')
    
    early_stopping = EarlyStopping(monitor="val_loss", patience=5)
    
    # Fits model on formatted inputs and outputs
    model.fit(convertedX, convertedY, epochs=100, 
              batch_size=16, verbose=0, validation_split=0.2,
              callbacks=[early_stopping])
    
    return model

# %%
def model_predict(model, X_test):
    convertedX = formatX(X_test)
    yhat = model.predict(convertedX)
    
    return yhat

# %%
def predict_returns(t, n, k, model, refit=True):
    inv = get_investable(t, n)
    X = apply_PCA(inv, k)
    
    returns_t = pd.DataFrame(index = inv.columns, columns = ['Pred', 'Actual'])
    
    for stock in inv.columns:
        y = define_y(inv, stock, n)
        X_train, y_train, X_test, y_test = train_test(X, y)
        
        if refit:
            model = model_fit(X_train, y_train)
            
        yhat = model_predict(model, X_test)[0][0]
        returns_t['Pred'].loc[stock] = yhat
        returns_t['Actual'].loc[stock] = y_test.values[0][0]
    
    return returns_t, model

# %%
def rank_stocks(returns, num_stocks):
    pred_returns = returns.sort_values(by = 'Pred', ascending = False)
    topn = pred_returns.head(num_stocks)
    botn = pred_returns.tail(num_stocks)
    
    return topn, botn

# %%
def portfolio_return(topn, botn, returns):
    return_t = topn['Actual'].mean() - botn['Actual'].mean()
    
    return return_t

# %%
def pipeline(n, k, num_stocks):

    time_range = returns.loc['2015':'2021'].index
    
    for i in range(len(time_range)):
        if time_range[i] in returns_monthly.index:
            time_range = time_range[i:]
            break
    
    portfolio = pd.DataFrame(index = time_range, columns = ['Portfolio Return'])
    current_model = Sequential()
    
    count = 0
    for t in time_range[:-1]:
        if t in returns_monthly.index:
            pred_actual, current_model = predict_returns(t, n, k, current_model, refit=True)
        else:
            pred_actual, current_model = predict_returns(t, n, k, current_model, refit=False)
        
        topn, botn = rank_stocks(pred_actual, num_stocks)
        return_t = portfolio_return(topn, botn, pred_actual)
        t_index = time_range.get_loc(t) + 1
        portfolio['Portfolio Return'].loc[time_range[t_index]] = return_t
        count +=1
        print(f'{(count/len(time_range))*100:.2f}% complete')
        
    portfolio['Portfolio Return'] = portfolio['Portfolio Return'].astype("float")
    
    return portfolio

# %%
portfolio = pipeline(50, 20, 5)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa5d3e58550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa5d4c190d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.06% complete
# 0.13% complete
# 0.19% complete
# 0.26% complete
# 0.32% complete
# 0.39% complete
# 0.45% complete
# 0.52% complete
# 0.58% complete
# 0.64% complete
# 0.71% complete
# 0.77% complete
# 0.84% complete
# 0.90% complete
# 0.97% complete
# 1.03% complete
# 1.09% complete
# 1.16% complete
# 1.22% complete
# 1.29% complete
# 1.35% complete
# 1.42% complete
# 1.48% complete
# 1.55% complete
# 1.61% complete
# 1.67% complete
# 1.74% complete
# 1.80% complete
# 1.87% complete
# 1.93% complete
# 2.00% complete
# 2.06% complete
# 2.12% complete
# 2.19% complete
# 2.25% complete
# 2.32% complete
# 2.38% complete
# 2.45% complete
# 2.51% complete
# 2.58% complete
# 2.64% complete
# 2.70% complete
# 2.77% complete
# 2.83% complete
# 2.90% complete
# 2.96% complete
# 3.03% complete
# 3.09% complete
# 3.16% complete
# 3.22% complete
# 3.28% complete
# 3.35% complete
# 3.41% complete
# 3.48% complete
# 3.54% complete
# 3.61% complete
# 3.67% complete
# 3.73% complete
# 3.80% complete
# 3.86% complete
# 3.93% complete
# 3.99% complete
# 4.06% complete
# 4.12% complete
# 4.19% complete
# 4.25% complete
# 4.31% complete
# 4.38% complete
# 4.44% complete
# 4.51% complete
# 4.57% complete
# 4.64% complete
# 4.70% complete
# 4.76% complete
# 4.83% complete
# 4.89% complete
# 4.96% complete
# 5.02% complete
# 5.09% complete
# 5.15% complete
# 5.22% complete
# 5.28% complete
# 5.34% complete
# 5.41% complete
# 5.47% complete
# 5.54% complete
# 5.60% complete
# 5.67% complete
# 5.73% complete
# 5.80% complete
# 5.86% complete
# 5.92% complete
# 5.99% complete
# 6.05% complete
# 6.12% complete
# 6.18% complete
# 6.25% complete
# 6.31% complete
# 6.37% complete
# 6.44% complete
# 6.50% complete
# 6.57% complete
# 6.63% complete
# 6.70% complete
# 6.76% complete
# 6.83% complete
# 6.89% complete
# 6.95% complete
# 7.02% complete
# 7.08% complete
# 7.15% complete
# 7.21% complete
# 7.28% complete
# 7.34% complete
# 7.41% complete
# 7.47% complete
# 7.53% complete
# 7.60% complete
# 7.66% complete
# 7.73% complete
# 7.79% complete
# 7.86% complete
# 7.92% complete
# 7.98% complete
# 8.05% complete
# 8.11% complete
# 8.18% complete
# 8.24% complete
# 8.31% complete
# 8.37% complete
# 8.44% complete
# 8.50% complete
# 8.56% complete
# 8.63% complete
# 8.69% complete
# 8.76% complete
# 8.82% complete
# 8.89% complete
# 8.95% complete
# 9.01% complete
# 9.08% complete
# 9.14% complete
# 9.21% complete
# 9.27% complete
# 9.34% complete
# 9.40% complete
# 9.47% complete
# 9.53% complete
# 9.59% complete
# 9.66% complete
# 9.72% complete
# 9.79% complete
# 9.85% complete
# 9.92% complete
# 9.98% complete
# 10.05% complete
# 10.11% complete
# 10.17% complete
# 10.24% complete
# 10.30% complete
# 10.37% complete
# 10.43% complete
# 10.50% complete
# 10.56% complete
# 10.62% complete
# 10.69% complete
# 10.75% complete
# 10.82% complete
# 10.88% complete
# 10.95% complete
# 11.01% complete
# 11.08% complete
# 11.14% complete
# 11.20% complete
# 11.27% complete
# 11.33% complete
# 11.40% complete
# 11.46% complete
# 11.53% complete
# 11.59% complete
# 11.65% complete
# 11.72% complete
# 11.78% complete
# 11.85% complete
# 11.91% complete
# 11.98% complete
# 12.04% complete
# 12.11% complete
# 12.17% complete
# 12.23% complete
# 12.30% complete
# 12.36% complete
# 12.43% complete
# 12.49% complete
# 12.56% complete
# 12.62% complete
# 12.69% complete
# 12.75% complete
# 12.81% complete
# 12.88% complete
# 12.94% complete
# 13.01% complete
# 13.07% complete
# 13.14% complete
# 13.20% complete
# 13.26% complete
# 13.33% complete
# 13.39% complete
# 13.46% complete
# 13.52% complete
# 13.59% complete
# 13.65% complete
# 13.72% complete
# 13.78% complete
# 13.84% complete
# 13.91% complete
# 13.97% complete
# 14.04% complete
# 14.10% complete
# 14.17% complete
# 14.23% complete
# 14.29% complete
# 14.36% complete
# 14.42% complete
# 14.49% complete
# 14.55% complete
# 14.62% complete
# 14.68% complete
# 14.75% complete
# 14.81% complete
# 14.87% complete
# 14.94% complete
# 15.00% complete
# 15.07% complete
# 15.13% complete
# 15.20% complete
# 15.26% complete
# 15.33% complete
# 15.39% complete
# 15.45% complete
# 15.52% complete
# 15.58% complete
# 15.65% complete
# 15.71% complete
# 15.78% complete
# 15.84% complete
# 15.90% complete
# 15.97% complete
# 16.03% complete
# 16.10% complete
# 16.16% complete
# 16.23% complete
# 16.29% complete
# 16.36% complete
# 16.42% complete
# 16.48% complete
# 16.55% complete
# 16.61% complete
# 16.68% complete
# 16.74% complete
# 16.81% complete
# 16.87% complete
# 16.93% complete
# 17.00% complete
# 17.06% complete
# 17.13% complete
# 17.19% complete
# 17.26% complete
# 17.32% complete
# 17.39% complete
# 17.45% complete
# 17.51% complete
# 17.58% complete
# 17.64% complete
# 17.71% complete
# 17.77% complete
# 17.84% complete
# 17.90% complete
# 17.97% complete
# 18.03% complete
# 18.09% complete
# 18.16% complete
# 18.22% complete
# 18.29% complete
# 18.35% complete
# 18.42% complete
# 18.48% complete
# 18.54% complete
# 18.61% complete
# 18.67% complete
# 18.74% complete
# 18.80% complete
# 18.87% complete
# 18.93% complete
# 19.00% complete
# 19.06% complete
# 19.12% complete
# 19.19% complete
# 19.25% complete
# 19.32% complete
# 19.38% complete
# 19.45% complete
# 19.51% complete
# 19.58% complete
# 19.64% complete
# 19.70% complete
# 19.77% complete
# 19.83% complete
# 19.90% complete
# 19.96% complete
# 20.03% complete
# 20.09% complete
# 20.15% complete
# 20.22% complete
# 20.28% complete
# 20.35% complete
# 20.41% complete
# 20.48% complete
# 20.54% complete
# 20.61% complete
# 20.67% complete
# 20.73% complete
# 20.80% complete
# 20.86% complete
# 20.93% complete
# 20.99% complete
# 21.06% complete
# 21.12% complete
# 21.18% complete
# 21.25% complete
# 21.31% complete
# 21.38% complete
# 21.44% complete
# 21.51% complete
# 21.57% complete
# 21.64% complete
# 21.70% complete
# 21.76% complete
# 21.83% complete
# 21.89% complete
# 21.96% complete
# 22.02% complete
# 22.09% complete
# 22.15% complete
# 22.22% complete
# 22.28% complete
# 22.34% complete
# 22.41% complete
# 22.47% complete
# 22.54% complete
# 22.60% complete
# 22.67% complete
# 22.73% complete
# 22.79% complete
# 22.86% complete
# 22.92% complete
# 22.99% complete
# 23.05% complete
# 23.12% complete
# 23.18% complete
# 23.25% complete
# 23.31% complete
# 23.37% complete
# 23.44% complete
# 23.50% complete
# 23.57% complete
# 23.63% complete
# 23.70% complete
# 23.76% complete
# 23.82% complete
# 23.89% complete
# 23.95% complete
# 24.02% complete
# 24.08% complete
# 24.15% complete
# 24.21% complete
# 24.28% complete
# 24.34% complete
# 24.40% complete
# 24.47% complete
# 24.53% complete
# 24.60% complete
# 24.66% complete
# 24.73% complete
# 24.79% complete
# 24.86% complete
# 24.92% complete
# 24.98% complete
# 25.05% complete
# 25.11% complete
# 25.18% complete
# 25.24% complete
# 25.31% complete
# 25.37% complete
# 25.43% complete
# 25.50% complete
# 25.56% complete
# 25.63% complete
# 25.69% complete
# 25.76% complete
# 25.82% complete
# 25.89% complete
# 25.95% complete
# 26.01% complete
# 26.08% complete
# 26.14% complete
# 26.21% complete
# 26.27% complete
# 26.34% complete
# 26.40% complete
# 26.46% complete
# 26.53% complete
# 26.59% complete
# 26.66% complete
# 26.72% complete
# 26.79% complete
# 26.85% complete
# 26.92% complete
# 26.98% complete
# 27.04% complete
# 27.11% complete
# 27.17% complete
# 27.24% complete
# 27.30% complete
# 27.37% complete
# 27.43% complete
# 27.50% complete
# 27.56% complete
# 27.62% complete
# 27.69% complete
# 27.75% complete
# 27.82% complete
# 27.88% complete
# 27.95% complete
# 28.01% complete
# 28.07% complete
# 28.14% complete
# 28.20% complete
# 28.27% complete
# 28.33% complete
# 28.40% complete
# 28.46% complete
# 28.53% complete
# 28.59% complete
# 28.65% complete
# 28.72% complete
# 28.78% complete
# 28.85% complete
# 28.91% complete
# 28.98% complete
# 29.04% complete
# 29.10% complete
# 29.17% complete
# 29.23% complete
# 29.30% complete
# 29.36% complete
# 29.43% complete
# 29.49% complete
# 29.56% complete
# 29.62% complete
# 29.68% complete
# 29.75% complete
# 29.81% complete
# 29.88% complete
# 29.94% complete
# 30.01% complete
# 30.07% complete
# 30.14% complete
# 30.20% complete
# 30.26% complete
# 30.33% complete
# 30.39% complete
# 30.46% complete
# 30.52% complete
# 30.59% complete
# 30.65% complete
# 30.71% complete
# 30.78% complete
# 30.84% complete
# 30.91% complete
# 30.97% complete
# 31.04% complete
# 31.10% complete
# 31.17% complete
# 31.23% complete
# 31.29% complete
# 31.36% complete
# 31.42% complete
# 31.49% complete
# 31.55% complete
# 31.62% complete
# 31.68% complete
# 31.75% complete
# 31.81% complete
# 31.87% complete
# 31.94% complete
# 32.00% complete
# 32.07% complete
# 32.13% complete
# 32.20% complete
# 32.26% complete
# 32.32% complete
# 32.39% complete
# 32.45% complete
# 32.52% complete
# 32.58% complete
# 32.65% complete
# 32.71% complete
# 32.78% complete
# 32.84% complete
# 32.90% complete
# 32.97% complete
# 33.03% complete
# 33.10% complete
# 33.16% complete
# 33.23% complete
# 33.29% complete
# 33.35% complete
# 33.42% complete
# 33.48% complete
# 33.55% complete
# 33.61% complete
# 33.68% complete
# 33.74% complete
# 33.81% complete
# 33.87% complete
# 33.93% complete
# 34.00% complete
# 34.06% complete
# 34.13% complete
# 34.19% complete
# 34.26% complete
# 34.32% complete
# 34.39% complete
# 34.45% complete
# 34.51% complete
# 34.58% complete
# 34.64% complete
# 34.71% complete
# 34.77% complete
# 34.84% complete
# 34.90% complete
# 34.96% complete
# 35.03% complete
# 35.09% complete
# 35.16% complete
# 35.22% complete
# 35.29% complete
# 35.35% complete
# 35.42% complete
# 35.48% complete
# 35.54% complete
# 35.61% complete
# 35.67% complete
# 35.74% complete
# 35.80% complete
# 35.87% complete
# 35.93% complete
# 35.99% complete
# 36.06% complete
# 36.12% complete
# 36.19% complete
# 36.25% complete
# 36.32% complete
# 36.38% complete
# 36.45% complete
# 36.51% complete
# 36.57% complete
# 36.64% complete
# 36.70% complete
# 36.77% complete
# 36.83% complete
# 36.90% complete
# 36.96% complete
# 37.03% complete
# 37.09% complete
# 37.15% complete
# 37.22% complete
# 37.28% complete
# 37.35% complete
# 37.41% complete
# 37.48% complete
# 37.54% complete
# 37.60% complete
# 37.67% complete
# 37.73% complete
# 37.80% complete
# 37.86% complete
# 37.93% complete
# 37.99% complete
# 38.06% complete
# 38.12% complete
# 38.18% complete
# 38.25% complete
# 38.31% complete
# 38.38% complete
# 38.44% complete
# 38.51% complete
# 38.57% complete
# 38.63% complete
# 38.70% complete
# 38.76% complete
# 38.83% complete
# 38.89% complete
# 38.96% complete
# 39.02% complete
# 39.09% complete
# 39.15% complete
# 39.21% complete
# 39.28% complete
# 39.34% complete
# 39.41% complete
# 39.47% complete
# 39.54% complete
# 39.60% complete
# 39.67% complete
# 39.73% complete
# 39.79% complete
# 39.86% complete
# 39.92% complete
# 39.99% complete
# 40.05% complete
# 40.12% complete
# 40.18% complete
# 40.24% complete
# 40.31% complete
# 40.37% complete
# 40.44% complete
# 40.50% complete
# 40.57% complete
# 40.63% complete
# 40.70% complete
# 40.76% complete
# 40.82% complete
# 40.89% complete
# 40.95% complete
# 41.02% complete
# 41.08% complete
# 41.15% complete
# 41.21% complete
# 41.27% complete
# 41.34% complete
# 41.40% complete
# 41.47% complete
# 41.53% complete
# 41.60% complete
# 41.66% complete
# 41.73% complete
# 41.79% complete
# 41.85% complete
# 41.92% complete
# 41.98% complete
# 42.05% complete
# 42.11% complete
# 42.18% complete
# 42.24% complete
# 42.31% complete
# 42.37% complete
# 42.43% complete
# 42.50% complete
# 42.56% complete
# 42.63% complete
# 42.69% complete
# 42.76% complete
# 42.82% complete
# 42.88% complete
# 42.95% complete
# 43.01% complete
# 43.08% complete
# 43.14% complete
# 43.21% complete
# 43.27% complete
# 43.34% complete
# 43.40% complete
# 43.46% complete
# 43.53% complete
# 43.59% complete
# 43.66% complete
# 43.72% complete
# 43.79% complete
# 43.85% complete
# 43.92% complete
# 43.98% complete
# 44.04% complete
# 44.11% complete
# 44.17% complete
# 44.24% complete
# 44.30% complete
# 44.37% complete
# 44.43% complete
# 44.49% complete
# 44.56% complete
# 44.62% complete
# 44.69% complete
# 44.75% complete
# 44.82% complete
# 44.88% complete
# 44.95% complete
# 45.01% complete
# 45.07% complete
# 45.14% complete
# 45.20% complete
# 45.27% complete
# 45.33% complete
# 45.40% complete
# 45.46% complete
# 45.52% complete
# 45.59% complete
# 45.65% complete
# 45.72% complete
# 45.78% complete
# 45.85% complete
# 45.91% complete
# 45.98% complete
# 46.04% complete
# 46.10% complete
# 46.17% complete
# 46.23% complete
# 46.30% complete
# 46.36% complete
# 46.43% complete
# 46.49% complete
# 46.56% complete
# 46.62% complete
# 46.68% complete
# 46.75% complete
# 46.81% complete
# 46.88% complete
# 46.94% complete
# 47.01% complete
# 47.07% complete
# 47.13% complete
# 47.20% complete
# 47.26% complete
# 47.33% complete
# 47.39% complete
# 47.46% complete
# 47.52% complete
# 47.59% complete
# 47.65% complete
# 47.71% complete
# 47.78% complete
# 47.84% complete
# 47.91% complete
# 47.97% complete
# 48.04% complete
# 48.10% complete
# 48.16% complete
# 48.23% complete
# 48.29% complete
# 48.36% complete
# 48.42% complete
# 48.49% complete
# 48.55% complete
# 48.62% complete
# 48.68% complete
# 48.74% complete
# 48.81% complete
# 48.87% complete
# 48.94% complete
# 49.00% complete
# 49.07% complete
# 49.13% complete
# 49.20% complete
# 49.26% complete
# 49.32% complete
# 49.39% complete
# 49.45% complete
# 49.52% complete
# 49.58% complete
# 49.65% complete
# 49.71% complete
# 49.77% complete
# 49.84% complete
# 49.90% complete
# 49.97% complete
# 50.03% complete
# 50.10% complete
# 50.16% complete
# 50.23% complete
# 50.29% complete
# 50.35% complete
# 50.42% complete
# 50.48% complete
# 50.55% complete
# 50.61% complete
# 50.68% complete
# 50.74% complete
# 50.80% complete
# 50.87% complete
# 50.93% complete
# 51.00% complete
# 51.06% complete
# 51.13% complete
# 51.19% complete
# 51.26% complete
# 51.32% complete
# 51.38% complete
# 51.45% complete
# 51.51% complete
# 51.58% complete
# 51.64% complete
# 51.71% complete
# 51.77% complete
# 51.84% complete
# 51.90% complete
# 51.96% complete
# 52.03% complete
# 52.09% complete
# 52.16% complete
# 52.22% complete
# 52.29% complete
# 52.35% complete
# 52.41% complete
# 52.48% complete
# 52.54% complete
# 52.61% complete
# 52.67% complete
# 52.74% complete
# 52.80% complete
# 52.87% complete
# 52.93% complete
# 52.99% complete
# 53.06% complete
# 53.12% complete
# 53.19% complete
# 53.25% complete
# 53.32% complete
# 53.38% complete
# 53.44% complete
# 53.51% complete
# 53.57% complete
# 53.64% complete
# 53.70% complete
# 53.77% complete
# 53.83% complete
# 53.90% complete
# 53.96% complete
# 54.02% complete
# 54.09% complete
# 54.15% complete
# 54.22% complete
# 54.28% complete
# 54.35% complete
# 54.41% complete
# 54.48% complete
# 54.54% complete
# 54.60% complete
# 54.67% complete
# 54.73% complete
# 54.80% complete
# 54.86% complete
# 54.93% complete
# 54.99% complete
# 55.05% complete
# 55.12% complete
# 55.18% complete
# 55.25% complete
# 55.31% complete
# 55.38% complete
# 55.44% complete
# 55.51% complete
# 55.57% complete
# 55.63% complete
# 55.70% complete
# 55.76% complete
# 55.83% complete
# 55.89% complete
# 55.96% complete
# 56.02% complete
# 56.08% complete
# 56.15% complete
# 56.21% complete
# 56.28% complete
# 56.34% complete
# 56.41% complete
# 56.47% complete
# 56.54% complete
# 56.60% complete
# 56.66% complete
# 56.73% complete
# 56.79% complete
# 56.86% complete
# 56.92% complete
# 56.99% complete
# 57.05% complete
# 57.12% complete
# 57.18% complete
# 57.24% complete
# 57.31% complete
# 57.37% complete
# 57.44% complete
# 57.50% complete
# 57.57% complete
# 57.63% complete
# 57.69% complete
# 57.76% complete
# 57.82% complete
# 57.89% complete
# 57.95% complete
# 58.02% complete
# 58.08% complete
# 58.15% complete
# 58.21% complete
# 58.27% complete
# 58.34% complete
# 58.40% complete
# 58.47% complete
# 58.53% complete
# 58.60% complete
# 58.66% complete
# 58.73% complete
# 58.79% complete
# 58.85% complete
# 58.92% complete
# 58.98% complete
# 59.05% complete
# 59.11% complete
# 59.18% complete
# 59.24% complete
# 59.30% complete
# 59.37% complete
# 59.43% complete
# 59.50% complete
# 59.56% complete
# 59.63% complete
# 59.69% complete
# 59.76% complete
# 59.82% complete
# 59.88% complete
# 59.95% complete
# 60.01% complete
# 60.08% complete
# 60.14% complete
# 60.21% complete
# 60.27% complete
# 60.33% complete
# 60.40% complete
# 60.46% complete
# 60.53% complete
# 60.59% complete
# 60.66% complete
# 60.72% complete
# 60.79% complete
# 60.85% complete
# 60.91% complete
# 60.98% complete
# 61.04% complete
# 61.11% complete
# 61.17% complete
# 61.24% complete
# 61.30% complete
# 61.37% complete
# 61.43% complete
# 61.49% complete
# 61.56% complete
# 61.62% complete
# 61.69% complete
# 61.75% complete
# 61.82% complete
# 61.88% complete
# 61.94% complete
# 62.01% complete
# 62.07% complete
# 62.14% complete
# 62.20% complete
# 62.27% complete
# 62.33% complete
# 62.40% complete
# 62.46% complete
# 62.52% complete
# 62.59% complete
# 62.65% complete
# 62.72% complete
# 62.78% complete
# 62.85% complete
# 62.91% complete
# 62.97% complete
# 63.04% complete
# 63.10% complete
# 63.17% complete
# 63.23% complete
# 63.30% complete
# 63.36% complete
# 63.43% complete
# 63.49% complete
# 63.55% complete
# 63.62% complete
# 63.68% complete
# 63.75% complete
# 63.81% complete
# 63.88% complete
# 63.94% complete
# 64.01% complete
# 64.07% complete
# 64.13% complete
# 64.20% complete
# 64.26% complete
# 64.33% complete
# 64.39% complete
# 64.46% complete
# 64.52% complete
# 64.58% complete
# 64.65% complete
# 64.71% complete
# 64.78% complete
# 64.84% complete
# 64.91% complete
# 64.97% complete
# 65.04% complete
# 65.10% complete
# 65.16% complete
# 65.23% complete
# 65.29% complete
# 65.36% complete
# 65.42% complete
# 65.49% complete
# 65.55% complete
# 65.61% complete
# 65.68% complete
# 65.74% complete
# 65.81% complete
# 65.87% complete
# 65.94% complete
# 66.00% complete
# 66.07% complete
# 66.13% complete
# 66.19% complete
# 66.26% complete
# 66.32% complete
# 66.39% complete
# 66.45% complete
# 66.52% complete
# 66.58% complete
# 66.65% complete
# 66.71% complete
# 66.77% complete
# 66.84% complete
# 66.90% complete
# 66.97% complete
# 67.03% complete
# 67.10% complete
# 67.16% complete
# 67.22% complete
# 67.29% complete
# 67.35% complete
# 67.42% complete
# 67.48% complete
# 67.55% complete
# 67.61% complete
# 67.68% complete
# 67.74% complete
# 67.80% complete
# 67.87% complete
# 67.93% complete
# 68.00% complete
# 68.06% complete
# 68.13% complete
# 68.19% complete
# 68.25% complete
# 68.32% complete
# 68.38% complete
# 68.45% complete
# 68.51% complete
# 68.58% complete
# 68.64% complete
# 68.71% complete
# 68.77% complete
# 68.83% complete
# 68.90% complete
# 68.96% complete
# 69.03% complete
# 69.09% complete
# 69.16% complete
# 69.22% complete
# 69.29% complete
# 69.35% complete
# 69.41% complete
# 69.48% complete
# 69.54% complete
# 69.61% complete
# 69.67% complete
# 69.74% complete
# 69.80% complete
# 69.86% complete
# 69.93% complete
# 69.99% complete
# 70.06% complete
# 70.12% complete
# 70.19% complete
# 70.25% complete
# 70.32% complete
# 70.38% complete
# 70.44% complete
# 70.51% complete
# 70.57% complete
# 70.64% complete
# 70.70% complete
# 70.77% complete
# 70.83% complete
# 70.90% complete
# 70.96% complete
# 71.02% complete
# 71.09% complete
# 71.15% complete
# 71.22% complete
# 71.28% complete
# 71.35% complete
# 71.41% complete
# 71.47% complete
# 71.54% complete
# 71.60% complete
# 71.67% complete
# 71.73% complete
# 71.80% complete
# 71.86% complete
# 71.93% complete
# 71.99% complete
# 72.05% complete
# 72.12% complete
# 72.18% complete
# 72.25% complete
# 72.31% complete
# 72.38% complete
# 72.44% complete
# 72.50% complete
# 72.57% complete
# 72.63% complete
# 72.70% complete
# 72.76% complete
# 72.83% complete
# 72.89% complete
# 72.96% complete
# 73.02% complete
# 73.08% complete
# 73.15% complete
# 73.21% complete
# 73.28% complete
# 73.34% complete
# 73.41% complete
# 73.47% complete
# 73.54% complete
# 73.60% complete
# 73.66% complete
# 73.73% complete
# 73.79% complete
# 73.86% complete
# 73.92% complete
# 73.99% complete
# 74.05% complete
# 74.11% complete
# 74.18% complete
# 74.24% complete
# 74.31% complete
# 74.37% complete
# 74.44% complete
# 74.50% complete
# 74.57% complete
# 74.63% complete
# 74.69% complete
# 74.76% complete
# 74.82% complete
# 74.89% complete
# 74.95% complete
# 75.02% complete
# 75.08% complete
# 75.14% complete
# 75.21% complete
# 75.27% complete
# 75.34% complete
# 75.40% complete
# 75.47% complete
# 75.53% complete
# 75.60% complete
# 75.66% complete
# 75.72% complete
# 75.79% complete
# 75.85% complete
# 75.92% complete
# 75.98% complete
# 76.05% complete
# 76.11% complete
# 76.18% complete
# 76.24% complete
# 76.30% complete
# 76.37% complete
# 76.43% complete
# 76.50% complete
# 76.56% complete
# 76.63% complete
# 76.69% complete
# 76.75% complete
# 76.82% complete
# 76.88% complete
# 76.95% complete
# 77.01% complete
# 77.08% complete
# 77.14% complete
# 77.21% complete
# 77.27% complete
# 77.33% complete
# 77.40% complete
# 77.46% complete
# 77.53% complete
# 77.59% complete
# 77.66% complete
# 77.72% complete
# 77.78% complete
# 77.85% complete
# 77.91% complete
# 77.98% complete
# 78.04% complete
# 78.11% complete
# 78.17% complete
# 78.24% complete
# 78.30% complete
# 78.36% complete
# 78.43% complete
# 78.49% complete
# 78.56% complete
# 78.62% complete
# 78.69% complete
# 78.75% complete
# 78.82% complete
# 78.88% complete
# 78.94% complete
# 79.01% complete
# 79.07% complete
# 79.14% complete
# 79.20% complete
# 79.27% complete
# 79.33% complete
# 79.39% complete
# 79.46% complete
# 79.52% complete
# 79.59% complete
# 79.65% complete
# 79.72% complete
# 79.78% complete
# 79.85% complete
# 79.91% complete
# 79.97% complete
# 80.04% complete
# 80.10% complete
# 80.17% complete
# 80.23% complete
# 80.30% complete
# 80.36% complete
# 80.42% complete
# 80.49% complete
# 80.55% complete
# 80.62% complete
# 80.68% complete
# 80.75% complete
# 80.81% complete
# 80.88% complete
# 80.94% complete
# 81.00% complete
# 81.07% complete
# 81.13% complete
# 81.20% complete
# 81.26% complete
# 81.33% complete
# 81.39% complete
# 81.46% complete
# 81.52% complete
# 81.58% complete
# 81.65% complete
# 81.71% complete
# 81.78% complete
# 81.84% complete
# 81.91% complete
# 81.97% complete
# 82.03% complete
# 82.10% complete
# 82.16% complete
# 82.23% complete
# 82.29% complete
# 82.36% complete
# 82.42% complete
# 82.49% complete
# 82.55% complete
# 82.61% complete
# 82.68% complete
# 82.74% complete
# 82.81% complete
# 82.87% complete
# 82.94% complete
# 83.00% complete
# 83.07% complete
# 83.13% complete
# 83.19% complete
# 83.26% complete
# 83.32% complete
# 83.39% complete
# 83.45% complete
# 83.52% complete
# 83.58% complete
# 83.64% complete
# 83.71% complete
# 83.77% complete
# 83.84% complete
# 83.90% complete
# 83.97% complete
# 84.03% complete
# 84.10% complete
# 84.16% complete
# 84.22% complete
# 84.29% complete
# 84.35% complete
# 84.42% complete
# 84.48% complete
# 84.55% complete
# 84.61% complete
# 84.67% complete
# 84.74% complete
# 84.80% complete
# 84.87% complete
# 84.93% complete
# 85.00% complete
# 85.06% complete
# 85.13% complete
# 85.19% complete
# 85.25% complete
# 85.32% complete
# 85.38% complete
# 85.45% complete
# 85.51% complete
# 85.58% complete
# 85.64% complete
# 85.71% complete
# 85.77% complete
# 85.83% complete
# 85.90% complete
# 85.96% complete
# 86.03% complete
# 86.09% complete
# 86.16% complete
# 86.22% complete
# 86.28% complete
# 86.35% complete
# 86.41% complete
# 86.48% complete
# 86.54% complete
# 86.61% complete
# 86.67% complete
# 86.74% complete
# 86.80% complete
# 86.86% complete
# 86.93% complete
# 86.99% complete
# 87.06% complete
# 87.12% complete
# 87.19% complete
# 87.25% complete
# 87.31% complete
# 87.38% complete
# 87.44% complete
# 87.51% complete
# 87.57% complete
# 87.64% complete
# 87.70% complete
# 87.77% complete
# 87.83% complete
# 87.89% complete
# 87.96% complete
# 88.02% complete
# 88.09% complete
# 88.15% complete
# 88.22% complete
# 88.28% complete
# 88.35% complete
# 88.41% complete
# 88.47% complete
# 88.54% complete
# 88.60% complete
# 88.67% complete
# 88.73% complete
# 88.80% complete
# 88.86% complete
# 88.92% complete
# 88.99% complete
# 89.05% complete
# 89.12% complete
# 89.18% complete
# 89.25% complete
# 89.31% complete
# 89.38% complete
# 89.44% complete
# 89.50% complete
# 89.57% complete
# 89.63% complete
# 89.70% complete
# 89.76% complete
# 89.83% complete
# 89.89% complete
# 89.95% complete
# 90.02% complete
# 90.08% complete
# 90.15% complete
# 90.21% complete
# 90.28% complete
# 90.34% complete
# 90.41% complete
# 90.47% complete
# 90.53% complete
# 90.60% complete
# 90.66% complete
# 90.73% complete
# 90.79% complete
# 90.86% complete
# 90.92% complete
# 90.99% complete
# 91.05% complete
# 91.11% complete
# 91.18% complete
# 91.24% complete
# 91.31% complete
# 91.37% complete
# 91.44% complete
# 91.50% complete
# 91.56% complete
# 91.63% complete
# 91.69% complete
# 91.76% complete
# 91.82% complete
# 91.89% complete
# 91.95% complete
# 92.02% complete
# 92.08% complete
# 92.14% complete
# 92.21% complete
# 92.27% complete
# 92.34% complete
# 92.40% complete
# 92.47% complete
# 92.53% complete
# 92.59% complete
# 92.66% complete
# 92.72% complete
# 92.79% complete
# 92.85% complete
# 92.92% complete
# 92.98% complete
# 93.05% complete
# 93.11% complete
# 93.17% complete
# 93.24% complete
# 93.30% complete
# 93.37% complete
# 93.43% complete
# 93.50% complete
# 93.56% complete
# 93.63% complete
# 93.69% complete
# 93.75% complete
# 93.82% complete
# 93.88% complete
# 93.95% complete
# 94.01% complete
# 94.08% complete
# 94.14% complete
# 94.20% complete
# 94.27% complete
# 94.33% complete
# 94.40% complete
# 94.46% complete
# 94.53% complete
# 94.59% complete
# 94.66% complete
# 94.72% complete
# 94.78% complete
# 94.85% complete
# 94.91% complete
# 94.98% complete
# 95.04% complete
# 95.11% complete
# 95.17% complete
# 95.24% complete
# 95.30% complete
# 95.36% complete
# 95.43% complete
# 95.49% complete
# 95.56% complete
# 95.62% complete
# 95.69% complete
# 95.75% complete
# 95.81% complete
# 95.88% complete
# 95.94% complete
# 96.01% complete
# 96.07% complete
# 96.14% complete
# 96.20% complete
# 96.27% complete
# 96.33% complete
# 96.39% complete
# 96.46% complete
# 96.52% complete
# 96.59% complete
# 96.65% complete
# 96.72% complete
# 96.78% complete
# 96.84% complete
# 96.91% complete
# 96.97% complete
# 97.04% complete
# 97.10% complete
# 97.17% complete
# 97.23% complete
# 97.30% complete
# 97.36% complete
# 97.42% complete
# 97.49% complete
# 97.55% complete
# 97.62% complete
# 97.68% complete
# 97.75% complete
# 97.81% complete
# 97.88% complete
# 97.94% complete
# 98.00% complete
# 98.07% complete
# 98.13% complete
# 98.20% complete
# 98.26% complete
# 98.33% complete
# 98.39% complete
# 98.45% complete
# 98.52% complete
# 98.58% complete
# 98.65% complete
# 98.71% complete
# 98.78% complete
# 98.84% complete
# 98.91% complete
# 98.97% complete
# 99.03% complete
# 99.10% complete
# 99.16% complete
# 99.23% complete
# 99.29% complete
# 99.36% complete
# 99.42% complete
# 99.48% complete
# 99.55% complete
# 99.61% complete
# 99.68% complete
# 99.74% complete
# 99.81% complete
# 99.87% complete
# 99.94% complete

# %%
portfolio.dropna(inplace = True)

# %%
portfolio
# Out:
#             Portfolio Return
# date
# 2015-04-01         -0.944199
# 2015-04-02          0.348428
# 2015-04-06          0.075472
# 2015-04-07         -0.711858
# 2015-04-08         -0.427156
# ...                      ...
# 2021-05-24         -0.601513
# 2021-05-25          1.410525
# 2021-05-26          0.721430
# 2021-05-27         -0.857396
# 2021-05-28         -1.549027
#
# [1552 rows x 1 columns]

# %%
portfolio.to_csv('results/LSTM.csv')

# %%
import matplotlib.ticker as ticker
import matplotlib.dates as mdates

fig, axes = plt.subplots(figsize=(30,15))
sns.barplot(x = portfolio.index, y = 'Portfolio Return', data = portfolio, color = 'grey')

axes.xaxis.set_major_locator(mdates.YearLocator())
axes.xaxis.set_minor_locator(mdates.MonthLocator())

ticklabels = [item.strftime('%Y') for item in portfolio.resample('Y').mean().index.to_period('Y')]

axes.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))

plt.xticks(rotation = 'vertical')
axes.set_title('Portfolio Returns')

sns.set(font_scale=2)
plt.axhline(0)

plt.tight_layout()


plt.show()

# %%
avg_return = portfolio['Portfolio Return'].mean()
print(f'Average return is {avg_return:.2f} %')
# Out:
# Average return is 0.02 %

# %%
rolling_avg = pd.read_csv('results/LSTM.csv', index_col = 'date', parse_dates = True).rolling(252).mean()

# %%
rolling_avg.dropna(inplace = True)

# %%
fig, axes = plt.subplots(figsize=(30,15))
sns.lineplot(x=rolling_avg.index, y="Portfolio Return", data=rolling_avg, color = '#0c8c84ff')
plt.xticks(rotation = 'vertical', fontsize = 25)
plt.yticks(fontsize = 20)
axes.set_title('LSTM: 12-Month Rolling Average Portfolio Returns', fontsize = 35)
axes.set_xlabel('Year', fontsize = 30)
axes.set_ylabel('Portfolio Return (%)', fontsize = 30)
plt.xlim([rolling_avg.index[0], rolling_avg.index[-1]])
plt.axhline(0, color = '#fcc43cff')
