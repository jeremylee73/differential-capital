# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Input
from tensorflow.keras.callbacks import EarlyStopping
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Pipeline psuedo code
#     n = look back window
#     k = number of PCs to keep
#
#     for each time point t:
#         p = number of stocks in investable universe at time t
#         Define an n x p feature matrix X (lagged returns)
#
#         Perform PCA on X
#         Keep the first k PCs in an n x k matrix Z
#
#     for each stock s in the investable universe at time t:
#         Define an n x 1 outcome vector y (future returns of stock s)
#         Perform a linear regression of y on Z
#         Predict y for stock s at time t+1

# %% [markdown]
# ## Data Preparation

# %%
returns = pd.read_pickle(".Data/returns.pkl")
returns = returns.iloc[1:]

# %%
drop_columns = []

for col in returns.columns:
    if returns[col].isnull().all() == True:
        drop_columns.append(col)
        
returns.drop(columns=drop_columns, inplace=True)

# %% [markdown]
# ## Pipeline

# %%
def get_investable(t, n):
    """"Find stocks in investable universe at time t+1
    (stocks in the S&P500 that have prices recorded for the last n days)"""
    
    df_investable = returns.copy(deep = True).sort_index(ascending = False)
    
    #add 1 date to get the test features in investable
    t = t + pd.DateOffset(1)
    n += 1
    
    #if t is now a non-trading day, advance until we reach a valid trading day
    while t not in df_investable.index:
        t = t + pd.DateOffset(1)
    
    t_index = df_investable.index.get_loc(t)
    
    #take n_rows worth of data upto time specified
    df_investable = df_investable.iloc[t_index:t_index + n]
    
    #find all stocks that exist in the S&P at this time period
    investable_universe = []
    for col in df_investable.columns:
        if ~df_investable[col].iloc[:n].isna().any():
            investable_universe.append(col)
        
    df_investable = df_investable[investable_universe]
    
    return df_investable

# %%
def define_y(inv, stock):
    y = inv[[stock]].shift(1)
    
    return y

# %%
def train_test(X, y):
    X_train = X.iloc[1:, :]
    X_test = X.iloc[0:1, :]
    y_train = y.iloc[1:]
    y_test = y.iloc[0:1]
    
    return X_train, y_train, X_test, y_test

# %%
t = pd.to_datetime('2020-05-22')
n = 200
k = 20

# %%
inv = get_investable(t, n)
inv.head()
# Out:
#               916328    936365    905271    905113    905802    905425  \
# date
# 2020-05-26 -2.175577 -3.588907  1.472157  5.578011  3.248408  1.447068
# 2020-05-22  1.194822  0.951510 -0.505222 -0.482703 -0.296359  1.822412
# 2020-05-21  0.333000 -3.085653 -1.776480 -2.509804 -0.211238 -0.488746
# 2020-05-20  2.119701  1.658554  1.597255  5.809129  3.227213  0.790770
# 2020-05-19 -2.270965  1.612017 -1.222013 -2.350081 -6.617797 -3.430145
#
#               906156    916305    992816    921093  ...    311917    69568X  \
# date                                                ...
# 2020-05-26  5.586029  7.338179 -0.677350  4.946297  ...  1.948106  0.243610
# 2020-05-22 -0.556607  0.277681  0.643838  0.740319  ... -0.071324 -1.295312
# 2020-05-21 -0.991954  2.746077 -0.745544 -0.650636  ...  3.275705  1.476286
# 2020-05-20  3.976622  1.483894  1.944817  1.522114  ...  0.777259  0.934394
# 2020-05-19 -1.300758 -2.882250 -0.577851 -2.737430  ... -0.239589 -0.690671
#
#               543755    77463M    29235J     131745    69487D    68157P  \
# date
# 2020-05-26  4.805492  3.562566  1.340390  -3.587887  3.742500  3.146853
# 2020-05-22 -0.126968 -5.856833 -0.128433   2.462057 -0.566286 -0.034953
# 2020-05-21 -0.379459 -6.607449 -3.374541  10.613691 -4.546332  1.265375
# 2020-05-20  0.739042 -4.281026  3.815470  12.958281  4.604200  2.624410
# 2020-05-19  1.552795  4.067060 -1.469583   6.651685 -2.968551 -1.157885
#
#               9110RA    292703
# date
# 2020-05-26  4.830054 -1.284488
# 2020-05-22  2.631579 -0.924499
# 2020-05-21  4.576000 -0.358240
# 2020-05-20  8.657858  3.520132
# 2020-05-19  3.453237 -1.106066
#
# [5 rows x 633 columns]

# %%
def formatX(investable_df):
    train_values = []
    # Iterates through each day in investable df and appends feature values to train_values
    for i in range(len(investable_df.index)):
        train_values.append(investable_df.iloc[i].values)
    train_values = np.array(train_values) # converts to numpy array
    train_values = np.reshape(train_values, (train_values.shape[0], 1, train_values.shape[1])) # reshapes to 3-dimensional
    return train_values

# %%
def simple_encoder(inv, k):
    encoding_dim = k
    sc = MinMaxScaler(feature_range = (0, 1))
    test_set_scaled = sc.fit_transform(inv)
    window_length = test_set_scaled.shape[1]
    input_window = Input(shape=(window_length,))
    # encoded representation of the input
    encoded = Dense(encoding_dim, activation="tanh")(input_window) #tanh, linear, leakyrelu
    # model mapping an input to its encoded representation
    encoder = Model(input_window, encoded)
    return pd.DataFrame(encoder.predict(test_set_scaled))

# %%
X = simple_encoder(inv,20)
X
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.117163  0.232526 -0.627714  0.257048 -0.079437 -0.862403 -0.604654
# 1   -0.188321  0.381116 -0.574381  0.078847  0.341966 -0.867535 -0.521050
# 2   -0.067919  0.332911 -0.606071  0.111680  0.149009 -0.884132 -0.594178
# 3   -0.332860  0.133965 -0.505243  0.150716  0.328217 -0.871158 -0.590220
# 4   -0.083871  0.290995 -0.604167  0.205029  0.229530 -0.835385 -0.601225
# ..        ...       ...       ...       ...       ...       ...       ...
# 196 -0.138828  0.307824 -0.472265  0.225882  0.141652 -0.786835 -0.476688
# 197 -0.250244  0.236449 -0.608234  0.107662  0.398092 -0.868793 -0.601921
# 198 -0.153338  0.290509 -0.518533 -0.042276  0.232114 -0.856822 -0.486957
# 199 -0.145600  0.349364 -0.464749  0.167183  0.007356 -0.838188 -0.462681
# 200 -0.253248  0.369155 -0.669534  0.211717  0.217054 -0.885182 -0.622102
#
#            7         8         9         10        11        12        13  \
# 0    0.216636  0.377655 -0.477555  0.416455 -0.670237  0.697726 -0.256196
# 1    0.121571  0.453498 -0.174813  0.366230 -0.521901  0.350530 -0.183959
# 2    0.007134  0.464494 -0.358787  0.248331 -0.637373  0.556795 -0.224892
# 3    0.156166  0.477016 -0.073496  0.514132 -0.668358  0.398834 -0.232142
# 4    0.075343  0.415516 -0.253529  0.482676 -0.572848  0.304804 -0.246647
# ..        ...       ...       ...       ...       ...       ...       ...
# 196  0.088941  0.310563 -0.185283  0.408228 -0.456421  0.432509 -0.287845
# 197  0.104254  0.515589 -0.265833  0.421217 -0.602780  0.435833 -0.256010
# 198  0.162637  0.443369 -0.345685  0.328953 -0.521876  0.410424 -0.282181
# 199  0.087982  0.398534 -0.236365  0.333567 -0.588887  0.442895 -0.259640
# 200  0.273830  0.486345 -0.141784  0.534841 -0.607177  0.410440 -0.230722
#
#            14        15        16        17        18        19
# 0   -0.343034 -0.707945 -0.101220 -0.275118 -0.720944 -0.492317
# 1   -0.470559 -0.579085 -0.019197 -0.393215 -0.479463 -0.616096
# 2   -0.540422 -0.546365 -0.012546 -0.351082 -0.550637 -0.612867
# 3   -0.363483 -0.536144 -0.114699 -0.319246 -0.634568 -0.553583
# 4   -0.380050 -0.562856 -0.054611 -0.205165 -0.435567 -0.613060
# ..        ...       ...       ...       ...       ...       ...
# 196 -0.498583 -0.507522 -0.025702 -0.234948 -0.325703 -0.424923
# 197 -0.460914 -0.645422 -0.068718 -0.306906 -0.600960 -0.499757
# 198 -0.478553 -0.485597 -0.066724 -0.220218 -0.465262 -0.471210
# 199 -0.569564 -0.521363  0.060799 -0.353625 -0.424325 -0.494383
# 200 -0.449418 -0.657497  0.065075 -0.243725 -0.645845 -0.570876
#
# [201 rows x 20 columns]

# %%
y = define_y(inv, inv.columns[0])

# %%
y
# Out:
#               916328
# date
# 2020-05-26       NaN
# 2020-05-22 -2.175577
# 2020-05-21  1.194822
# 2020-05-20  0.333000
# 2020-05-19  2.119701
# ...              ...
# 2019-08-14  0.000000
# 2019-08-13 -3.395097
# 2019-08-12  2.634066
# 2019-08-09 -2.262757
# 2019-08-08  1.238897
#
# [201 rows x 1 columns]

# %%
X_train, y_train, X_test, y_test = train_test(X, y)

# %%
y_train
# Out:
#               916328
# date
# 2020-05-22 -2.175577
# 2020-05-21  1.194822
# 2020-05-20  0.333000
# 2020-05-19  2.119701
# 2020-05-18 -2.270965
# ...              ...
# 2019-08-14  0.000000
# 2019-08-13 -3.395097
# 2019-08-12  2.634066
# 2019-08-09 -2.262757
# 2019-08-08  1.238897
#
# [200 rows x 1 columns]

# %%
y_test
# Out:
#             916328
# date
# 2020-05-26     NaN

# %%
def model_fit(X_train, y_train):
    model = sklearn.linear_model.LinearRegression()
    model.fit(X_train, y_train)
    
    return model

# %%
def model_predict(model, X_test):
    yhat = model.predict(X_test)
    
    return yhat

# %%
def predict_returns(t, n, k):
    inv = get_investable(t, n)
    X = simple_encoder(inv, k)
    
    returns_t = pd.DataFrame(index = inv.columns, columns = ['Pred', 'Actual'])
    
    for stock in inv.columns:
        y = define_y(inv, stock)
        X_train, y_train, X_test, y_test = train_test(X, y)
        model = model_fit(X_train, y_train)
        yhat = model_predict(model, X_test)[0][0]
        returns_t['Pred'].loc[stock] = yhat
        returns_t['Actual'].loc[stock] = y_test.values[0][0]
    
    return returns_t

# %%
def rank_stocks(returns, num_stocks):
    pred_returns = returns.sort_values(by = 'Pred', ascending = False)
    topn = pred_returns.head(num_stocks)
    botn = pred_returns.tail(num_stocks)
    
    return topn, botn

# %%
def portfolio_return(topn, botn, returns):
    return_t = topn['Actual'].mean() - botn['Actual'].mean()
    
    return return_t

# %%
def pipeline(n, k, num_stocks):

    time_range = returns.loc['2007':'2021'].index[:-1]
    
    portfolio = pd.DataFrame(index = time_range, columns = ['Portfolio Return'])
    
    count = 0
    for t in time_range:
        pred_actual = predict_returns(t, n, k)
        topn, botn = rank_stocks(pred_actual, num_stocks)
        return_t = portfolio_return(topn, botn, pred_actual)
        t_index = time_range.get_loc(t) + 1
        portfolio['Portfolio Return'].loc[time_range[t_index]] = return_t
        
        count +=1
        print(f'{(count/len(time_range))*100:.2f}% complete')
    
    portfolio['Portfolio Return'] = portfolio['Portfolio Return'].astype('float')
    
    return portfolio

# %%
portfolio = pipeline(200, 20, 5)
# Out:
# 0.03% complete
# 0.06% complete
# 0.08% complete
# 0.11% complete
# 0.14% complete
# 0.17% complete
# 0.19% complete
# 0.22% complete
# 0.25% complete
# 0.28% complete
# 0.30% complete
# 0.33% complete
# 0.36% complete
# 0.39% complete
# 0.41% complete
# 0.44% complete
# 0.47% complete
# 0.50% complete
# 0.52% complete
# 0.55% complete
# 0.58% complete
# 0.61% complete
# 0.63% complete
# 0.66% complete
# 0.69% complete
# 0.72% complete
# 0.74% complete
# 0.77% complete
# 0.80% complete
# 0.83% complete
# 0.85% complete
# 0.88% complete
# 0.91% complete
# 0.94% complete
# 0.97% complete
# 0.99% complete
# 1.02% complete
# 1.05% complete
# 1.08% complete
# 1.10% complete
# 1.13% complete
# 1.16% complete
# 1.19% complete
# 1.21% complete
# 1.24% complete
# 1.27% complete
# 1.30% complete
# 1.32% complete
# 1.35% complete
# 1.38% complete
# 1.41% complete
# 1.43% complete
# 1.46% complete
# 1.49% complete
# 1.52% complete
# 1.54% complete
# 1.57% complete
# 1.60% complete
# 1.63% complete
# 1.65% complete
# 1.68% complete
# 1.71% complete
# 1.74% complete
# 1.77% complete
# 1.79% complete
# 1.82% complete
# 1.85% complete
# 1.88% complete
# 1.90% complete
# 1.93% complete
# 1.96% complete
# 1.99% complete
# 2.01% complete
# 2.04% complete
# 2.07% complete
# 2.10% complete
# 2.12% complete
# 2.15% complete
# 2.18% complete
# 2.21% complete
# 2.23% complete
# 2.26% complete
# 2.29% complete
# 2.32% complete
# 2.34% complete
# 2.37% complete
# 2.40% complete
# 2.43% complete
# 2.45% complete
# 2.48% complete
# 2.51% complete
# 2.54% complete
# 2.56% complete
# 2.59% complete
# 2.62% complete
# 2.65% complete
# 2.68% complete
# 2.70% complete
# 2.73% complete
# 2.76% complete
# 2.79% complete
# 2.81% complete
# 2.84% complete
# 2.87% complete
# 2.90% complete
# 2.92% complete
# 2.95% complete
# 2.98% complete
# 3.01% complete
# 3.03% complete
# 3.06% complete
# 3.09% complete
# 3.12% complete
# 3.14% complete
# 3.17% complete
# 3.20% complete
# 3.23% complete
# 3.25% complete
# 3.28% complete
# 3.31% complete
# 3.34% complete
# 3.36% complete
# 3.39% complete
# 3.42% complete
# 3.45% complete
# 3.47% complete
# 3.50% complete
# 3.53% complete
# 3.56% complete
# 3.59% complete
# 3.61% complete
# 3.64% complete
# 3.67% complete
# 3.70% complete
# 3.72% complete
# 3.75% complete
# 3.78% complete
# 3.81% complete
# 3.83% complete
# 3.86% complete
# 3.89% complete
# 3.92% complete
# 3.94% complete
# 3.97% complete
# 4.00% complete
# 4.03% complete
# 4.05% complete
# 4.08% complete
# 4.11% complete
# 4.14% complete
# 4.16% complete
# 4.19% complete
# 4.22% complete
# 4.25% complete
# 4.27% complete
# 4.30% complete
# 4.33% complete
# 4.36% complete
# 4.38% complete
# 4.41% complete
# 4.44% complete
# 4.47% complete
# 4.50% complete
# 4.52% complete
# 4.55% complete
# 4.58% complete
# 4.61% complete
# 4.63% complete
# 4.66% complete
# 4.69% complete
# 4.72% complete
# 4.74% complete
# 4.77% complete
# 4.80% complete
# 4.83% complete
# 4.85% complete
# 4.88% complete
# 4.91% complete
# 4.94% complete
# 4.96% complete
# 4.99% complete
# 5.02% complete
# 5.05% complete
# 5.07% complete
# 5.10% complete
# 5.13% complete
# 5.16% complete
# 5.18% complete
# 5.21% complete
# 5.24% complete
# 5.27% complete
# 5.30% complete
# 5.32% complete
# 5.35% complete
# 5.38% complete
# 5.41% complete
# 5.43% complete
# 5.46% complete
# 5.49% complete
# 5.52% complete
# 5.54% complete
# 5.57% complete
# 5.60% complete
# 5.63% complete
# 5.65% complete
# 5.68% complete
# 5.71% complete
# 5.74% complete
# 5.76% complete
# 5.79% complete
# 5.82% complete
# 5.85% complete
# 5.87% complete
# 5.90% complete
# 5.93% complete
# 5.96% complete
# 5.98% complete
# 6.01% complete
# 6.04% complete
# 6.07% complete
# 6.09% complete
# 6.12% complete
# 6.15% complete
# 6.18% complete
# 6.21% complete
# 6.23% complete
# 6.26% complete
# 6.29% complete
# 6.32% complete
# 6.34% complete
# 6.37% complete
# 6.40% complete
# 6.43% complete
# 6.45% complete
# 6.48% complete
# 6.51% complete
# 6.54% complete
# 6.56% complete
# 6.59% complete
# 6.62% complete
# 6.65% complete
# 6.67% complete
# 6.70% complete
# 6.73% complete
# 6.76% complete
# 6.78% complete
# 6.81% complete
# 6.84% complete
# 6.87% complete
# 6.89% complete
# 6.92% complete
# 6.95% complete
# 6.98% complete
# 7.00% complete
# 7.03% complete
# 7.06% complete
# 7.09% complete
# 7.12% complete
# 7.14% complete
# 7.17% complete
# 7.20% complete
# 7.23% complete
# 7.25% complete
# 7.28% complete
# 7.31% complete
# 7.34% complete
# 7.36% complete
# 7.39% complete
# 7.42% complete
# 7.45% complete
# 7.47% complete
# 7.50% complete
# 7.53% complete
# 7.56% complete
# 7.58% complete
# 7.61% complete
# 7.64% complete
# 7.67% complete
# 7.69% complete
# 7.72% complete
# 7.75% complete
# 7.78% complete
# 7.80% complete
# 7.83% complete
# 7.86% complete
# 7.89% complete
# 7.92% complete
# 7.94% complete
# 7.97% complete
# 8.00% complete
# 8.03% complete
# 8.05% complete
# 8.08% complete
# 8.11% complete
# 8.14% complete
# 8.16% complete
# 8.19% complete
# 8.22% complete
# 8.25% complete
# 8.27% complete
# 8.30% complete
# 8.33% complete
# 8.36% complete
# 8.38% complete
# 8.41% complete
# 8.44% complete
# 8.47% complete
# 8.49% complete
# 8.52% complete
# 8.55% complete
# 8.58% complete
# 8.60% complete
# 8.63% complete
# 8.66% complete
# 8.69% complete
# 8.71% complete
# 8.74% complete
# 8.77% complete
# 8.80% complete
# 8.83% complete
# 8.85% complete
# 8.88% complete
# 8.91% complete
# 8.94% complete
# 8.96% complete
# 8.99% complete
# 9.02% complete
# 9.05% complete
# 9.07% complete
# 9.10% complete
# 9.13% complete
# 9.16% complete
# 9.18% complete
# 9.21% complete
# 9.24% complete
# 9.27% complete
# 9.29% complete
# 9.32% complete
# 9.35% complete
# 9.38% complete
# 9.40% complete
# 9.43% complete
# 9.46% complete
# 9.49% complete
# 9.51% complete
# 9.54% complete
# 9.57% complete
# 9.60% complete
# 9.62% complete
# 9.65% complete
# 9.68% complete
# 9.71% complete
# 9.74% complete
# 9.76% complete
# 9.79% complete
# 9.82% complete
# 9.85% complete
# 9.87% complete
# 9.90% complete
# 9.93% complete
# 9.96% complete
# 9.98% complete
# 10.01% complete
# 10.04% complete
# 10.07% complete
# 10.09% complete
# 10.12% complete
# 10.15% complete
# 10.18% complete
# 10.20% complete
# 10.23% complete
# 10.26% complete
# 10.29% complete
# 10.31% complete
# 10.34% complete
# 10.37% complete
# 10.40% complete
# 10.42% complete
# 10.45% complete
# 10.48% complete
# 10.51% complete
# 10.54% complete
# 10.56% complete
# 10.59% complete
# 10.62% complete
# 10.65% complete
# 10.67% complete
# 10.70% complete
# 10.73% complete
# 10.76% complete
# 10.78% complete
# 10.81% complete
# 10.84% complete
# 10.87% complete
# 10.89% complete
# 10.92% complete
# 10.95% complete
# 10.98% complete
# 11.00% complete
# 11.03% complete
# 11.06% complete
# 11.09% complete
# 11.11% complete
# 11.14% complete
# 11.17% complete
# 11.20% complete
# 11.22% complete
# 11.25% complete
# 11.28% complete
# 11.31% complete
# 11.33% complete
# 11.36% complete
# 11.39% complete
# 11.42% complete
# 11.45% complete
# 11.47% complete
# 11.50% complete
# 11.53% complete
# 11.56% complete
# 11.58% complete
# 11.61% complete
# 11.64% complete
# 11.67% complete
# 11.69% complete
# 11.72% complete
# 11.75% complete
# 11.78% complete
# 11.80% complete
# 11.83% complete
# 11.86% complete
# 11.89% complete
# 11.91% complete
# 11.94% complete
# 11.97% complete
# 12.00% complete
# 12.02% complete
# 12.05% complete
# 12.08% complete
# 12.11% complete
# 12.13% complete
# 12.16% complete
# 12.19% complete
# 12.22% complete
# 12.24% complete
# 12.27% complete
# 12.30% complete
# 12.33% complete
# 12.36% complete
# 12.38% complete
# 12.41% complete
# 12.44% complete
# 12.47% complete
# 12.49% complete
# 12.52% complete
# 12.55% complete
# 12.58% complete
# 12.60% complete
# 12.63% complete
# 12.66% complete
# 12.69% complete
# 12.71% complete
# 12.74% complete
# 12.77% complete
# 12.80% complete
# 12.82% complete
# 12.85% complete
# 12.88% complete
# 12.91% complete
# 12.93% complete
# 12.96% complete
# 12.99% complete
# 13.02% complete
# 13.04% complete
# 13.07% complete
# 13.10% complete
# 13.13% complete
# 13.15% complete
# 13.18% complete
# 13.21% complete
# 13.24% complete
# 13.27% complete
# 13.29% complete
# 13.32% complete
# 13.35% complete
# 13.38% complete
# 13.40% complete
# 13.43% complete
# 13.46% complete
# 13.49% complete
# 13.51% complete
# 13.54% complete
# 13.57% complete
# 13.60% complete
# 13.62% complete
# 13.65% complete
# 13.68% complete
# 13.71% complete
# 13.73% complete
# 13.76% complete
# 13.79% complete
# 13.82% complete
# 13.84% complete
# 13.87% complete
# 13.90% complete
# 13.93% complete
# 13.95% complete
# 13.98% complete
# 14.01% complete
# 14.04% complete
# 14.07% complete
# 14.09% complete
# 14.12% complete
# 14.15% complete
# 14.18% complete
# 14.20% complete
# 14.23% complete
# 14.26% complete
# 14.29% complete
# 14.31% complete
# 14.34% complete
# 14.37% complete
# 14.40% complete
# 14.42% complete
# 14.45% complete
# 14.48% complete
# 14.51% complete
# 14.53% complete
# 14.56% complete
# 14.59% complete
# 14.62% complete
# 14.64% complete
# 14.67% complete
# 14.70% complete
# 14.73% complete
# 14.75% complete
# 14.78% complete
# 14.81% complete
# 14.84% complete
# 14.86% complete
# 14.89% complete
# 14.92% complete
# 14.95% complete
# 14.98% complete
# 15.00% complete
# 15.03% complete
# 15.06% complete
# 15.09% complete
# 15.11% complete
# 15.14% complete
# 15.17% complete
# 15.20% complete
# 15.22% complete
# 15.25% complete
# 15.28% complete
# 15.31% complete
# 15.33% complete
# 15.36% complete
# 15.39% complete
# 15.42% complete
# 15.44% complete
# 15.47% complete
# 15.50% complete
# 15.53% complete
# 15.55% complete
# 15.58% complete
# 15.61% complete
# 15.64% complete
# 15.66% complete
# 15.69% complete
# 15.72% complete
# 15.75% complete
# 15.77% complete
# 15.80% complete
# 15.83% complete
# 15.86% complete
# 15.89% complete
# 15.91% complete
# 15.94% complete
# 15.97% complete
# 16.00% complete
# 16.02% complete
# 16.05% complete
# 16.08% complete
# 16.11% complete
# 16.13% complete
# 16.16% complete
# 16.19% complete
# 16.22% complete
# 16.24% complete
# 16.27% complete
# 16.30% complete
# 16.33% complete
# 16.35% complete
# 16.38% complete
# 16.41% complete
# 16.44% complete
# 16.46% complete
# 16.49% complete
# 16.52% complete
# 16.55% complete
# 16.57% complete
# 16.60% complete
# 16.63% complete
# 16.66% complete
# 16.69% complete
# 16.71% complete
# 16.74% complete
# 16.77% complete
# 16.80% complete
# 16.82% complete
# 16.85% complete
# 16.88% complete
# 16.91% complete
# 16.93% complete
# 16.96% complete
# 16.99% complete
# 17.02% complete
# 17.04% complete
# 17.07% complete
# 17.10% complete
# 17.13% complete
# 17.15% complete
# 17.18% complete
# 17.21% complete
# 17.24% complete
# 17.26% complete
# 17.29% complete
# 17.32% complete
# 17.35% complete
# 17.37% complete
# 17.40% complete
# 17.43% complete
# 17.46% complete
# 17.48% complete
# 17.51% complete
# 17.54% complete
# 17.57% complete
# 17.60% complete
# 17.62% complete
# 17.65% complete
# 17.68% complete
# 17.71% complete
# 17.73% complete
# 17.76% complete
# 17.79% complete
# 17.82% complete
# 17.84% complete
# 17.87% complete
# 17.90% complete
# 17.93% complete
# 17.95% complete
# 17.98% complete
# 18.01% complete
# 18.04% complete
# 18.06% complete
# 18.09% complete
# 18.12% complete
# 18.15% complete
# 18.17% complete
# 18.20% complete
# 18.23% complete
# 18.26% complete
# 18.28% complete
# 18.31% complete
# 18.34% complete
# 18.37% complete
# 18.39% complete
# 18.42% complete
# 18.45% complete
# 18.48% complete
# 18.51% complete
# 18.53% complete
# 18.56% complete
# 18.59% complete
# 18.62% complete
# 18.64% complete
# 18.67% complete
# 18.70% complete
# 18.73% complete
# 18.75% complete
# 18.78% complete
# 18.81% complete
# 18.84% complete
# 18.86% complete
# 18.89% complete
# 18.92% complete
# 18.95% complete
# 18.97% complete
# 19.00% complete
# 19.03% complete
# 19.06% complete
# 19.08% complete
# 19.11% complete
# 19.14% complete
# 19.17% complete
# 19.19% complete
# 19.22% complete
# 19.25% complete
# 19.28% complete
# 19.31% complete
# 19.33% complete
# 19.36% complete
# 19.39% complete
# 19.42% complete
# 19.44% complete
# 19.47% complete
# 19.50% complete
# 19.53% complete
# 19.55% complete
# 19.58% complete
# 19.61% complete
# 19.64% complete
# 19.66% complete
# 19.69% complete
# 19.72% complete
# 19.75% complete
# 19.77% complete
# 19.80% complete
# 19.83% complete
# 19.86% complete
# 19.88% complete
# 19.91% complete
# 19.94% complete
# 19.97% complete
# 19.99% complete
# 20.02% complete
# 20.05% complete
# 20.08% complete
# 20.10% complete
# 20.13% complete
# 20.16% complete
# 20.19% complete
# 20.22% complete
# 20.24% complete
# 20.27% complete
# 20.30% complete
# 20.33% complete
# 20.35% complete
# 20.38% complete
# 20.41% complete
# 20.44% complete
# 20.46% complete
# 20.49% complete
# 20.52% complete
# 20.55% complete
# 20.57% complete
# 20.60% complete
# 20.63% complete
# 20.66% complete
# 20.68% complete
# 20.71% complete
# 20.74% complete
# 20.77% complete
# 20.79% complete
# 20.82% complete
# 20.85% complete
# 20.88% complete
# 20.90% complete
# 20.93% complete
# 20.96% complete
# 20.99% complete
# 21.01% complete
# 21.04% complete
# 21.07% complete
# 21.10% complete
# 21.13% complete
# 21.15% complete
# 21.18% complete
# 21.21% complete
# 21.24% complete
# 21.26% complete
# 21.29% complete
# 21.32% complete
# 21.35% complete
# 21.37% complete
# 21.40% complete
# 21.43% complete
# 21.46% complete
# 21.48% complete
# 21.51% complete
# 21.54% complete
# 21.57% complete
# 21.59% complete
# 21.62% complete
# 21.65% complete
# 21.68% complete
# 21.70% complete
# 21.73% complete
# 21.76% complete
# 21.79% complete
# 21.81% complete
# 21.84% complete
# 21.87% complete
# 21.90% complete
# 21.92% complete
# 21.95% complete
# 21.98% complete
# 22.01% complete
# 22.04% complete
# 22.06% complete
# 22.09% complete
# 22.12% complete
# 22.15% complete
# 22.17% complete
# 22.20% complete
# 22.23% complete
# 22.26% complete
# 22.28% complete
# 22.31% complete
# 22.34% complete
# 22.37% complete
# 22.39% complete
# 22.42% complete
# 22.45% complete
# 22.48% complete
# 22.50% complete
# 22.53% complete
# 22.56% complete
# 22.59% complete
# 22.61% complete
# 22.64% complete
# 22.67% complete
# 22.70% complete
# 22.72% complete
# 22.75% complete
# 22.78% complete
# 22.81% complete
# 22.84% complete
# 22.86% complete
# 22.89% complete
# 22.92% complete
# 22.95% complete
# 22.97% complete
# 23.00% complete
# 23.03% complete
# 23.06% complete
# 23.08% complete
# 23.11% complete
# 23.14% complete
# 23.17% complete
# 23.19% complete
# 23.22% complete
# 23.25% complete
# 23.28% complete
# 23.30% complete
# 23.33% complete
# 23.36% complete
# 23.39% complete
# 23.41% complete
# 23.44% complete
# 23.47% complete
# 23.50% complete
# 23.52% complete
# 23.55% complete
# 23.58% complete
# 23.61% complete
# 23.63% complete
# 23.66% complete
# 23.69% complete
# 23.72% complete
# 23.75% complete
# 23.77% complete
# 23.80% complete
# 23.83% complete
# 23.86% complete
# 23.88% complete
# 23.91% complete
# 23.94% complete
# 23.97% complete
# 23.99% complete
# 24.02% complete
# 24.05% complete
# 24.08% complete
# 24.10% complete
# 24.13% complete
# 24.16% complete
# 24.19% complete
# 24.21% complete
# 24.24% complete
# 24.27% complete
# 24.30% complete
# 24.32% complete
# 24.35% complete
# 24.38% complete
# 24.41% complete
# 24.43% complete
# 24.46% complete
# 24.49% complete
# 24.52% complete
# 24.54% complete
# 24.57% complete
# 24.60% complete
# 24.63% complete
# 24.66% complete
# 24.68% complete
# 24.71% complete
# 24.74% complete
# 24.77% complete
# 24.79% complete
# 24.82% complete
# 24.85% complete
# 24.88% complete
# 24.90% complete
# 24.93% complete
# 24.96% complete
# 24.99% complete
# 25.01% complete
# 25.04% complete
# 25.07% complete
# 25.10% complete
# 25.12% complete
# 25.15% complete
# 25.18% complete
# 25.21% complete
# 25.23% complete
# 25.26% complete
# 25.29% complete
# 25.32% complete
# 25.34% complete
# 25.37% complete
# 25.40% complete
# 25.43% complete
# 25.46% complete
# 25.48% complete
# 25.51% complete
# 25.54% complete
# 25.57% complete
# 25.59% complete
# 25.62% complete
# 25.65% complete
# 25.68% complete
# 25.70% complete
# 25.73% complete
# 25.76% complete
# 25.79% complete
# 25.81% complete
# 25.84% complete
# 25.87% complete
# 25.90% complete
# 25.92% complete
# 25.95% complete
# 25.98% complete
# 26.01% complete
# 26.03% complete
# 26.06% complete
# 26.09% complete
# 26.12% complete
# 26.14% complete
# 26.17% complete
# 26.20% complete
# 26.23% complete
# 26.25% complete
# 26.28% complete
# 26.31% complete
# 26.34% complete
# 26.37% complete
# 26.39% complete
# 26.42% complete
# 26.45% complete
# 26.48% complete
# 26.50% complete
# 26.53% complete
# 26.56% complete
# 26.59% complete
# 26.61% complete
# 26.64% complete
# 26.67% complete
# 26.70% complete
# 26.72% complete
# 26.75% complete
# 26.78% complete
# 26.81% complete
# 26.83% complete
# 26.86% complete
# 26.89% complete
# 26.92% complete
# 26.94% complete
# 26.97% complete
# 27.00% complete
# 27.03% complete
# 27.05% complete
# 27.08% complete
# 27.11% complete
# 27.14% complete
# 27.16% complete
# 27.19% complete
# 27.22% complete
# 27.25% complete
# 27.28% complete
# 27.30% complete
# 27.33% complete
# 27.36% complete
# 27.39% complete
# 27.41% complete
# 27.44% complete
# 27.47% complete
# 27.50% complete
# 27.52% complete
# 27.55% complete
# 27.58% complete
# 27.61% complete
# 27.63% complete
# 27.66% complete
# 27.69% complete
# 27.72% complete
# 27.74% complete
# 27.77% complete
# 27.80% complete
# 27.83% complete
# 27.85% complete
# 27.88% complete
# 27.91% complete
# 27.94% complete
# 27.96% complete
# 27.99% complete
# 28.02% complete
# 28.05% complete
# 28.08% complete
# 28.10% complete
# 28.13% complete
# 28.16% complete
# 28.19% complete
# 28.21% complete
# 28.24% complete
# 28.27% complete
# 28.30% complete
# 28.32% complete
# 28.35% complete
# 28.38% complete
# 28.41% complete
# 28.43% complete
# 28.46% complete
# 28.49% complete
# 28.52% complete
# 28.54% complete
# 28.57% complete
# 28.60% complete
# 28.63% complete
# 28.65% complete
# 28.68% complete
# 28.71% complete
# 28.74% complete
# 28.76% complete
# 28.79% complete
# 28.82% complete
# 28.85% complete
# 28.87% complete
# 28.90% complete
# 28.93% complete
# 28.96% complete
# 28.99% complete
# 29.01% complete
# 29.04% complete
# 29.07% complete
# 29.10% complete
# 29.12% complete
# 29.15% complete
# 29.18% complete
# 29.21% complete
# 29.23% complete
# 29.26% complete
# 29.29% complete
# 29.32% complete
# 29.34% complete
# 29.37% complete
# 29.40% complete
# 29.43% complete
# 29.45% complete
# 29.48% complete
# 29.51% complete
# 29.54% complete
# 29.56% complete
# 29.59% complete
# 29.62% complete
# 29.65% complete
# 29.67% complete
# 29.70% complete
# 29.73% complete
# 29.76% complete
# 29.78% complete
# 29.81% complete
# 29.84% complete
# 29.87% complete
# 29.90% complete
# 29.92% complete
# 29.95% complete
# 29.98% complete
# 30.01% complete
# 30.03% complete
# 30.06% complete
# 30.09% complete
# 30.12% complete
# 30.14% complete
# 30.17% complete
# 30.20% complete
# 30.23% complete
# 30.25% complete
# 30.28% complete
# 30.31% complete
# 30.34% complete
# 30.36% complete
# 30.39% complete
# 30.42% complete
# 30.45% complete
# 30.47% complete
# 30.50% complete
# 30.53% complete
# 30.56% complete
# 30.58% complete
# 30.61% complete
# 30.64% complete
# 30.67% complete
# 30.69% complete
# 30.72% complete
# 30.75% complete
# 30.78% complete
# 30.81% complete
# 30.83% complete
# 30.86% complete
# 30.89% complete
# 30.92% complete
# 30.94% complete
# 30.97% complete
# 31.00% complete
# 31.03% complete
# 31.05% complete
# 31.08% complete
# 31.11% complete
# 31.14% complete
# 31.16% complete
# 31.19% complete
# 31.22% complete
# 31.25% complete
# 31.27% complete
# 31.30% complete
# 31.33% complete
# 31.36% complete
# 31.38% complete
# 31.41% complete
# 31.44% complete
# 31.47% complete
# 31.49% complete
# 31.52% complete
# 31.55% complete
# 31.58% complete
# 31.61% complete
# 31.63% complete
# 31.66% complete
# 31.69% complete
# 31.72% complete
# 31.74% complete
# 31.77% complete
# 31.80% complete
# 31.83% complete
# 31.85% complete
# 31.88% complete
# 31.91% complete
# 31.94% complete
# 31.96% complete
# 31.99% complete
# 32.02% complete
# 32.05% complete
# 32.07% complete
# 32.10% complete
# 32.13% complete
# 32.16% complete
# 32.18% complete
# 32.21% complete
# 32.24% complete
# 32.27% complete
# 32.29% complete
# 32.32% complete
# 32.35% complete
# 32.38% complete
# 32.40% complete
# 32.43% complete
# 32.46% complete
# 32.49% complete
# 32.52% complete
# 32.54% complete
# 32.57% complete
# 32.60% complete
# 32.63% complete
# 32.65% complete
# 32.68% complete
# 32.71% complete
# 32.74% complete
# 32.76% complete
# 32.79% complete
# 32.82% complete
# 32.85% complete
# 32.87% complete
# 32.90% complete
# 32.93% complete
# 32.96% complete
# 32.98% complete
# 33.01% complete
# 33.04% complete
# 33.07% complete
# 33.09% complete
# 33.12% complete
# 33.15% complete
# 33.18% complete
# 33.20% complete
# 33.23% complete
# 33.26% complete
# 33.29% complete
# 33.31% complete
# 33.34% complete
# 33.37% complete
# 33.40% complete
# 33.43% complete
# 33.45% complete
# 33.48% complete
# 33.51% complete
# 33.54% complete
# 33.56% complete
# 33.59% complete
# 33.62% complete
# 33.65% complete
# 33.67% complete
# 33.70% complete
# 33.73% complete
# 33.76% complete
# 33.78% complete
# 33.81% complete
# 33.84% complete
# 33.87% complete
# 33.89% complete
# 33.92% complete
# 33.95% complete
# 33.98% complete
# 34.00% complete
# 34.03% complete
# 34.06% complete
# 34.09% complete
# 34.11% complete
# 34.14% complete
# 34.17% complete
# 34.20% complete
# 34.23% complete
# 34.25% complete
# 34.28% complete
# 34.31% complete
# 34.34% complete
# 34.36% complete
# 34.39% complete
# 34.42% complete
# 34.45% complete
# 34.47% complete
# 34.50% complete
# 34.53% complete
# 34.56% complete
# 34.58% complete
# 34.61% complete
# 34.64% complete
# 34.67% complete
# 34.69% complete
# 34.72% complete
# 34.75% complete
# 34.78% complete
# 34.80% complete
# 34.83% complete
# 34.86% complete
# 34.89% complete
# 34.91% complete
# 34.94% complete
# 34.97% complete
# 35.00% complete
# 35.02% complete
# 35.05% complete
# 35.08% complete
# 35.11% complete
# 35.14% complete
# 35.16% complete
# 35.19% complete
# 35.22% complete
# 35.25% complete
# 35.27% complete
# 35.30% complete
# 35.33% complete
# 35.36% complete
# 35.38% complete
# 35.41% complete
# 35.44% complete
# 35.47% complete
# 35.49% complete
# 35.52% complete
# 35.55% complete
# 35.58% complete
# 35.60% complete
# 35.63% complete
# 35.66% complete
# 35.69% complete
# 35.71% complete
# 35.74% complete
# 35.77% complete
# 35.80% complete
# 35.82% complete
# 35.85% complete
# 35.88% complete
# 35.91% complete
# 35.93% complete
# 35.96% complete
# 35.99% complete
# 36.02% complete
# 36.05% complete
# 36.07% complete
# 36.10% complete
# 36.13% complete
# 36.16% complete
# 36.18% complete
# 36.21% complete
# 36.24% complete
# 36.27% complete
# 36.29% complete
# 36.32% complete
# 36.35% complete
# 36.38% complete
# 36.40% complete
# 36.43% complete
# 36.46% complete
# 36.49% complete
# 36.51% complete
# 36.54% complete
# 36.57% complete
# 36.60% complete
# 36.62% complete
# 36.65% complete
# 36.68% complete
# 36.71% complete
# 36.73% complete
# 36.76% complete
# 36.79% complete
# 36.82% complete
# 36.85% complete
# 36.87% complete
# 36.90% complete
# 36.93% complete
# 36.96% complete
# 36.98% complete
# 37.01% complete
# 37.04% complete
# 37.07% complete
# 37.09% complete
# 37.12% complete
# 37.15% complete
# 37.18% complete
# 37.20% complete
# 37.23% complete
# 37.26% complete
# 37.29% complete
# 37.31% complete
# 37.34% complete
# 37.37% complete
# 37.40% complete
# 37.42% complete
# 37.45% complete
# 37.48% complete
# 37.51% complete
# 37.53% complete
# 37.56% complete
# 37.59% complete
# 37.62% complete
# 37.64% complete
# 37.67% complete
# 37.70% complete
# 37.73% complete
# 37.76% complete
# 37.78% complete
# 37.81% complete
# 37.84% complete
# 37.87% complete
# 37.89% complete
# 37.92% complete
# 37.95% complete
# 37.98% complete
# 38.00% complete
# 38.03% complete
# 38.06% complete
# 38.09% complete
# 38.11% complete
# 38.14% complete
# 38.17% complete
# 38.20% complete
# 38.22% complete
# 38.25% complete
# 38.28% complete
# 38.31% complete
# 38.33% complete
# 38.36% complete
# 38.39% complete
# 38.42% complete
# 38.44% complete
# 38.47% complete
# 38.50% complete
# 38.53% complete
# 38.55% complete
# 38.58% complete
# 38.61% complete
# 38.64% complete
# 38.67% complete
# 38.69% complete
# 38.72% complete
# 38.75% complete
# 38.78% complete
# 38.80% complete
# 38.83% complete
# 38.86% complete
# 38.89% complete
# 38.91% complete
# 38.94% complete
# 38.97% complete
# 39.00% complete
# 39.02% complete
# 39.05% complete
# 39.08% complete
# 39.11% complete
# 39.13% complete
# 39.16% complete
# 39.19% complete
# 39.22% complete
# 39.24% complete
# 39.27% complete
# 39.30% complete
# 39.33% complete
# 39.35% complete
# 39.38% complete
# 39.41% complete
# 39.44% complete
# 39.46% complete
# 39.49% complete
# 39.52% complete
# 39.55% complete
# 39.58% complete
# 39.60% complete
# 39.63% complete
# 39.66% complete
# 39.69% complete
# 39.71% complete
# 39.74% complete
# 39.77% complete
# 39.80% complete
# 39.82% complete
# 39.85% complete
# 39.88% complete
# 39.91% complete
# 39.93% complete
# 39.96% complete
# 39.99% complete
# 40.02% complete
# 40.04% complete
# 40.07% complete
# 40.10% complete
# 40.13% complete
# 40.15% complete
# 40.18% complete
# 40.21% complete
# 40.24% complete
# 40.26% complete
# 40.29% complete
# 40.32% complete
# 40.35% complete
# 40.38% complete
# 40.40% complete
# 40.43% complete
# 40.46% complete
# 40.49% complete
# 40.51% complete
# 40.54% complete
# 40.57% complete
# 40.60% complete
# 40.62% complete
# 40.65% complete
# 40.68% complete
# 40.71% complete
# 40.73% complete
# 40.76% complete
# 40.79% complete
# 40.82% complete
# 40.84% complete
# 40.87% complete
# 40.90% complete
# 40.93% complete
# 40.95% complete
# 40.98% complete
# 41.01% complete
# 41.04% complete
# 41.06% complete
# 41.09% complete
# 41.12% complete
# 41.15% complete
# 41.17% complete
# 41.20% complete
# 41.23% complete
# 41.26% complete
# 41.29% complete
# 41.31% complete
# 41.34% complete
# 41.37% complete
# 41.40% complete
# 41.42% complete
# 41.45% complete
# 41.48% complete
# 41.51% complete
# 41.53% complete
# 41.56% complete
# 41.59% complete
# 41.62% complete
# 41.64% complete
# 41.67% complete
# 41.70% complete
# 41.73% complete
# 41.75% complete
# 41.78% complete
# 41.81% complete
# 41.84% complete
# 41.86% complete
# 41.89% complete
# 41.92% complete
# 41.95% complete
# 41.97% complete
# 42.00% complete
# 42.03% complete
# 42.06% complete
# 42.08% complete
# 42.11% complete
# 42.14% complete
# 42.17% complete
# 42.20% complete
# 42.22% complete
# 42.25% complete
# 42.28% complete
# 42.31% complete
# 42.33% complete
# 42.36% complete
# 42.39% complete
# 42.42% complete
# 42.44% complete
# 42.47% complete
# 42.50% complete
# 42.53% complete
# 42.55% complete
# 42.58% complete
# 42.61% complete
# 42.64% complete
# 42.66% complete
# 42.69% complete
# 42.72% complete
# 42.75% complete
# 42.77% complete
# 42.80% complete
# 42.83% complete
# 42.86% complete
# 42.88% complete
# 42.91% complete
# 42.94% complete
# 42.97% complete
# 43.00% complete
# 43.02% complete
# 43.05% complete
# 43.08% complete
# 43.11% complete
# 43.13% complete
# 43.16% complete
# 43.19% complete
# 43.22% complete
# 43.24% complete
# 43.27% complete
# 43.30% complete
# 43.33% complete
# 43.35% complete
# 43.38% complete
# 43.41% complete
# 43.44% complete
# 43.46% complete
# 43.49% complete
# 43.52% complete
# 43.55% complete
# 43.57% complete
# 43.60% complete
# 43.63% complete
# 43.66% complete
# 43.68% complete
# 43.71% complete
# 43.74% complete
# 43.77% complete
# 43.79% complete
# 43.82% complete
# 43.85% complete
# 43.88% complete
# 43.91% complete
# 43.93% complete
# 43.96% complete
# 43.99% complete
# 44.02% complete
# 44.04% complete
# 44.07% complete
# 44.10% complete
# 44.13% complete
# 44.15% complete
# 44.18% complete
# 44.21% complete
# 44.24% complete
# 44.26% complete
# 44.29% complete
# 44.32% complete
# 44.35% complete
# 44.37% complete
# 44.40% complete
# 44.43% complete
# 44.46% complete
# 44.48% complete
# 44.51% complete
# 44.54% complete
# 44.57% complete
# 44.59% complete
# 44.62% complete
# 44.65% complete
# 44.68% complete
# 44.70% complete
# 44.73% complete
# 44.76% complete
# 44.79% complete
# 44.82% complete
# 44.84% complete
# 44.87% complete
# 44.90% complete
# 44.93% complete
# 44.95% complete
# 44.98% complete
# 45.01% complete
# 45.04% complete
# 45.06% complete
# 45.09% complete
# 45.12% complete
# 45.15% complete
# 45.17% complete
# 45.20% complete
# 45.23% complete
# 45.26% complete
# 45.28% complete
# 45.31% complete
# 45.34% complete
# 45.37% complete
# 45.39% complete
# 45.42% complete
# 45.45% complete
# 45.48% complete
# 45.50% complete
# 45.53% complete
# 45.56% complete
# 45.59% complete
# 45.62% complete
# 45.64% complete
# 45.67% complete
# 45.70% complete
# 45.73% complete
# 45.75% complete
# 45.78% complete
# 45.81% complete
# 45.84% complete
# 45.86% complete
# 45.89% complete
# 45.92% complete
# 45.95% complete
# 45.97% complete
# 46.00% complete
# 46.03% complete
# 46.06% complete
# 46.08% complete
# 46.11% complete
# 46.14% complete
# 46.17% complete
# 46.19% complete
# 46.22% complete
# 46.25% complete
# 46.28% complete
# 46.30% complete
# 46.33% complete
# 46.36% complete
# 46.39% complete
# 46.41% complete
# 46.44% complete
# 46.47% complete
# 46.50% complete
# 46.53% complete
# 46.55% complete
# 46.58% complete
# 46.61% complete
# 46.64% complete
# 46.66% complete
# 46.69% complete
# 46.72% complete
# 46.75% complete
# 46.77% complete
# 46.80% complete
# 46.83% complete
# 46.86% complete
# 46.88% complete
# 46.91% complete
# 46.94% complete
# 46.97% complete
# 46.99% complete
# 47.02% complete
# 47.05% complete
# 47.08% complete
# 47.10% complete
# 47.13% complete
# 47.16% complete
# 47.19% complete
# 47.21% complete
# 47.24% complete
# 47.27% complete
# 47.30% complete
# 47.32% complete
# 47.35% complete
# 47.38% complete
# 47.41% complete
# 47.44% complete
# 47.46% complete
# 47.49% complete
# 47.52% complete
# 47.55% complete
# 47.57% complete
# 47.60% complete
# 47.63% complete
# 47.66% complete
# 47.68% complete
# 47.71% complete
# 47.74% complete
# 47.77% complete
# 47.79% complete
# 47.82% complete
# 47.85% complete
# 47.88% complete
# 47.90% complete
# 47.93% complete
# 47.96% complete
# 47.99% complete
# 48.01% complete
# 48.04% complete
# 48.07% complete
# 48.10% complete
# 48.12% complete
# 48.15% complete
# 48.18% complete
# 48.21% complete
# 48.23% complete
# 48.26% complete
# 48.29% complete
# 48.32% complete
# 48.35% complete
# 48.37% complete
# 48.40% complete
# 48.43% complete
# 48.46% complete
# 48.48% complete
# 48.51% complete
# 48.54% complete
# 48.57% complete
# 48.59% complete
# 48.62% complete
# 48.65% complete
# 48.68% complete
# 48.70% complete
# 48.73% complete
# 48.76% complete
# 48.79% complete
# 48.81% complete
# 48.84% complete
# 48.87% complete
# 48.90% complete
# 48.92% complete
# 48.95% complete
# 48.98% complete
# 49.01% complete
# 49.03% complete
# 49.06% complete
# 49.09% complete
# 49.12% complete
# 49.15% complete
# 49.17% complete
# 49.20% complete
# 49.23% complete
# 49.26% complete
# 49.28% complete
# 49.31% complete
# 49.34% complete
# 49.37% complete
# 49.39% complete
# 49.42% complete
# 49.45% complete
# 49.48% complete
# 49.50% complete
# 49.53% complete
# 49.56% complete
# 49.59% complete
# 49.61% complete
# 49.64% complete
# 49.67% complete
# 49.70% complete
# 49.72% complete
# 49.75% complete
# 49.78% complete
# 49.81% complete
# 49.83% complete
# 49.86% complete
# 49.89% complete
# 49.92% complete
# 49.94% complete
# 49.97% complete
# 50.00% complete
# 50.03% complete
# 50.06% complete
# 50.08% complete
# 50.11% complete
# 50.14% complete
# 50.17% complete
# 50.19% complete
# 50.22% complete
# 50.25% complete
# 50.28% complete
# 50.30% complete
# 50.33% complete
# 50.36% complete
# 50.39% complete
# 50.41% complete
# 50.44% complete
# 50.47% complete
# 50.50% complete
# 50.52% complete
# 50.55% complete
# 50.58% complete
# 50.61% complete
# 50.63% complete
# 50.66% complete
# 50.69% complete
# 50.72% complete
# 50.74% complete
# 50.77% complete
# 50.80% complete
# 50.83% complete
# 50.85% complete
# 50.88% complete
# 50.91% complete
# 50.94% complete
# 50.97% complete
# 50.99% complete
# 51.02% complete
# 51.05% complete
# 51.08% complete
# 51.10% complete
# 51.13% complete
# 51.16% complete
# 51.19% complete
# 51.21% complete
# 51.24% complete
# 51.27% complete
# 51.30% complete
# 51.32% complete
# 51.35% complete
# 51.38% complete
# 51.41% complete
# 51.43% complete
# 51.46% complete
# 51.49% complete
# 51.52% complete
# 51.54% complete
# 51.57% complete
# 51.60% complete
# 51.63% complete
# 51.65% complete
# 51.68% complete
# 51.71% complete
# 51.74% complete
# 51.77% complete
# 51.79% complete
# 51.82% complete
# 51.85% complete
# 51.88% complete
# 51.90% complete
# 51.93% complete
# 51.96% complete
# 51.99% complete
# 52.01% complete
# 52.04% complete
# 52.07% complete
# 52.10% complete
# 52.12% complete
# 52.15% complete
# 52.18% complete
# 52.21% complete
# 52.23% complete
# 52.26% complete
# 52.29% complete
# 52.32% complete
# 52.34% complete
# 52.37% complete
# 52.40% complete
# 52.43% complete
# 52.45% complete
# 52.48% complete
# 52.51% complete
# 52.54% complete
# 52.56% complete
# 52.59% complete
# 52.62% complete
# 52.65% complete
# 52.68% complete
# 52.70% complete
# 52.73% complete
# 52.76% complete
# 52.79% complete
# 52.81% complete
# 52.84% complete
# 52.87% complete
# 52.90% complete
# 52.92% complete
# 52.95% complete
# 52.98% complete
# 53.01% complete
# 53.03% complete
# 53.06% complete
# 53.09% complete
# 53.12% complete
# 53.14% complete
# 53.17% complete
# 53.20% complete
# 53.23% complete
# 53.25% complete
# 53.28% complete
# 53.31% complete
# 53.34% complete
# 53.36% complete
# 53.39% complete
# 53.42% complete
# 53.45% complete
# 53.47% complete
# 53.50% complete
# 53.53% complete
# 53.56% complete
# 53.59% complete
# 53.61% complete
# 53.64% complete
# 53.67% complete
# 53.70% complete
# 53.72% complete
# 53.75% complete
# 53.78% complete
# 53.81% complete
# 53.83% complete
# 53.86% complete
# 53.89% complete
# 53.92% complete
# 53.94% complete
# 53.97% complete
# 54.00% complete
# 54.03% complete
# 54.05% complete
# 54.08% complete
# 54.11% complete
# 54.14% complete
# 54.16% complete
# 54.19% complete
# 54.22% complete
# 54.25% complete
# 54.27% complete
# 54.30% complete
# 54.33% complete
# 54.36% complete
# 54.38% complete
# 54.41% complete
# 54.44% complete
# 54.47% complete
# 54.50% complete
# 54.52% complete
# 54.55% complete
# 54.58% complete
# 54.61% complete
# 54.63% complete
# 54.66% complete
# 54.69% complete
# 54.72% complete
# 54.74% complete
# 54.77% complete
# 54.80% complete
# 54.83% complete
# 54.85% complete
# 54.88% complete
# 54.91% complete
# 54.94% complete
# 54.96% complete
# 54.99% complete
# 55.02% complete
# 55.05% complete
# 55.07% complete
# 55.10% complete
# 55.13% complete
# 55.16% complete
# 55.18% complete
# 55.21% complete
# 55.24% complete
# 55.27% complete
# 55.30% complete
# 55.32% complete
# 55.35% complete
# 55.38% complete
# 55.41% complete
# 55.43% complete
# 55.46% complete
# 55.49% complete
# 55.52% complete
# 55.54% complete
# 55.57% complete
# 55.60% complete
# 55.63% complete
# 55.65% complete
# 55.68% complete
# 55.71% complete
# 55.74% complete
# 55.76% complete
# 55.79% complete
# 55.82% complete
# 55.85% complete
# 55.87% complete
# 55.90% complete
# 55.93% complete
# 55.96% complete
# 55.98% complete
# 56.01% complete
# 56.04% complete
# 56.07% complete
# 56.09% complete
# 56.12% complete
# 56.15% complete
# 56.18% complete
# 56.21% complete
# 56.23% complete
# 56.26% complete
# 56.29% complete
# 56.32% complete
# 56.34% complete
# 56.37% complete
# 56.40% complete
# 56.43% complete
# 56.45% complete
# 56.48% complete
# 56.51% complete
# 56.54% complete
# 56.56% complete
# 56.59% complete
# 56.62% complete
# 56.65% complete
# 56.67% complete
# 56.70% complete
# 56.73% complete
# 56.76% complete
# 56.78% complete
# 56.81% complete
# 56.84% complete
# 56.87% complete
# 56.89% complete
# 56.92% complete
# 56.95% complete
# 56.98% complete
# 57.00% complete
# 57.03% complete
# 57.06% complete
# 57.09% complete
# 57.12% complete
# 57.14% complete
# 57.17% complete
# 57.20% complete
# 57.23% complete
# 57.25% complete
# 57.28% complete
# 57.31% complete
# 57.34% complete
# 57.36% complete
# 57.39% complete
# 57.42% complete
# 57.45% complete
# 57.47% complete
# 57.50% complete
# 57.53% complete
# 57.56% complete
# 57.58% complete
# 57.61% complete
# 57.64% complete
# 57.67% complete
# 57.69% complete
# 57.72% complete
# 57.75% complete
# 57.78% complete
# 57.80% complete
# 57.83% complete
# 57.86% complete
# 57.89% complete
# 57.92% complete
# 57.94% complete
# 57.97% complete
# 58.00% complete
# 58.03% complete
# 58.05% complete
# 58.08% complete
# 58.11% complete
# 58.14% complete
# 58.16% complete
# 58.19% complete
# 58.22% complete
# 58.25% complete
# 58.27% complete
# 58.30% complete
# 58.33% complete
# 58.36% complete
# 58.38% complete
# 58.41% complete
# 58.44% complete
# 58.47% complete
# 58.49% complete
# 58.52% complete
# 58.55% complete
# 58.58% complete
# 58.60% complete
# 58.63% complete
# 58.66% complete
# 58.69% complete
# 58.71% complete
# 58.74% complete
# 58.77% complete
# 58.80% complete
# 58.83% complete
# 58.85% complete
# 58.88% complete
# 58.91% complete
# 58.94% complete
# 58.96% complete
# 58.99% complete
# 59.02% complete
# 59.05% complete
# 59.07% complete
# 59.10% complete
# 59.13% complete
# 59.16% complete
# 59.18% complete
# 59.21% complete
# 59.24% complete
# 59.27% complete
# 59.29% complete
# 59.32% complete
# 59.35% complete
# 59.38% complete
# 59.40% complete
# 59.43% complete
# 59.46% complete
# 59.49% complete
# 59.51% complete
# 59.54% complete
# 59.57% complete
# 59.60% complete
# 59.62% complete
# 59.65% complete
# 59.68% complete
# 59.71% complete
# 59.74% complete
# 59.76% complete
# 59.79% complete
# 59.82% complete
# 59.85% complete
# 59.87% complete
# 59.90% complete
# 59.93% complete
# 59.96% complete
# 59.98% complete
# 60.01% complete
# 60.04% complete
# 60.07% complete
# 60.09% complete
# 60.12% complete
# 60.15% complete
# 60.18% complete
# 60.20% complete
# 60.23% complete
# 60.26% complete
# 60.29% complete
# 60.31% complete
# 60.34% complete
# 60.37% complete
# 60.40% complete
# 60.42% complete
# 60.45% complete
# 60.48% complete
# 60.51% complete
# 60.54% complete
# 60.56% complete
# 60.59% complete
# 60.62% complete
# 60.65% complete
# 60.67% complete
# 60.70% complete
# 60.73% complete
# 60.76% complete
# 60.78% complete
# 60.81% complete
# 60.84% complete
# 60.87% complete
# 60.89% complete
# 60.92% complete
# 60.95% complete
# 60.98% complete
# 61.00% complete
# 61.03% complete
# 61.06% complete
# 61.09% complete
# 61.11% complete
# 61.14% complete
# 61.17% complete
# 61.20% complete
# 61.22% complete
# 61.25% complete
# 61.28% complete
# 61.31% complete
# 61.33% complete
# 61.36% complete
# 61.39% complete
# 61.42% complete
# 61.45% complete
# 61.47% complete
# 61.50% complete
# 61.53% complete
# 61.56% complete
# 61.58% complete
# 61.61% complete
# 61.64% complete
# 61.67% complete
# 61.69% complete
# 61.72% complete
# 61.75% complete
# 61.78% complete
# 61.80% complete
# 61.83% complete
# 61.86% complete
# 61.89% complete
# 61.91% complete
# 61.94% complete
# 61.97% complete
# 62.00% complete
# 62.02% complete
# 62.05% complete
# 62.08% complete
# 62.11% complete
# 62.13% complete
# 62.16% complete
# 62.19% complete
# 62.22% complete
# 62.24% complete
# 62.27% complete
# 62.30% complete
# 62.33% complete
# 62.36% complete
# 62.38% complete
# 62.41% complete
# 62.44% complete
# 62.47% complete
# 62.49% complete
# 62.52% complete
# 62.55% complete
# 62.58% complete
# 62.60% complete
# 62.63% complete
# 62.66% complete
# 62.69% complete
# 62.71% complete
# 62.74% complete
# 62.77% complete
# 62.80% complete
# 62.82% complete
# 62.85% complete
# 62.88% complete
# 62.91% complete
# 62.93% complete
# 62.96% complete
# 62.99% complete
# 63.02% complete
# 63.04% complete
# 63.07% complete
# 63.10% complete
# 63.13% complete
# 63.15% complete
# 63.18% complete
# 63.21% complete
# 63.24% complete
# 63.27% complete
# 63.29% complete
# 63.32% complete
# 63.35% complete
# 63.38% complete
# 63.40% complete
# 63.43% complete
# 63.46% complete
# 63.49% complete
# 63.51% complete
# 63.54% complete
# 63.57% complete
# 63.60% complete
# 63.62% complete
# 63.65% complete
# 63.68% complete
# 63.71% complete
# 63.73% complete
# 63.76% complete
# 63.79% complete
# 63.82% complete
# 63.84% complete
# 63.87% complete
# 63.90% complete
# 63.93% complete
# 63.95% complete
# 63.98% complete
# 64.01% complete
# 64.04% complete
# 64.07% complete
# 64.09% complete
# 64.12% complete
# 64.15% complete
# 64.18% complete
# 64.20% complete
# 64.23% complete
# 64.26% complete
# 64.29% complete
# 64.31% complete
# 64.34% complete
# 64.37% complete
# 64.40% complete
# 64.42% complete
# 64.45% complete
# 64.48% complete
# 64.51% complete
# 64.53% complete
# 64.56% complete
# 64.59% complete
# 64.62% complete
# 64.64% complete
# 64.67% complete
# 64.70% complete
# 64.73% complete
# 64.75% complete
# 64.78% complete
# 64.81% complete
# 64.84% complete
# 64.86% complete
# 64.89% complete
# 64.92% complete
# 64.95% complete
# 64.98% complete
# 65.00% complete
# 65.03% complete
# 65.06% complete
# 65.09% complete
# 65.11% complete
# 65.14% complete
# 65.17% complete
# 65.20% complete
# 65.22% complete
# 65.25% complete
# 65.28% complete
# 65.31% complete
# 65.33% complete
# 65.36% complete
# 65.39% complete
# 65.42% complete
# 65.44% complete
# 65.47% complete
# 65.50% complete
# 65.53% complete
# 65.55% complete
# 65.58% complete
# 65.61% complete
# 65.64% complete
# 65.66% complete
# 65.69% complete
# 65.72% complete
# 65.75% complete
# 65.77% complete
# 65.80% complete
# 65.83% complete
# 65.86% complete
# 65.89% complete
# 65.91% complete
# 65.94% complete
# 65.97% complete
# 66.00% complete
# 66.02% complete
# 66.05% complete
# 66.08% complete
# 66.11% complete
# 66.13% complete
# 66.16% complete
# 66.19% complete
# 66.22% complete
# 66.24% complete
# 66.27% complete
# 66.30% complete
# 66.33% complete
# 66.35% complete
# 66.38% complete
# 66.41% complete
# 66.44% complete
# 66.46% complete
# 66.49% complete
# 66.52% complete
# 66.55% complete
# 66.57% complete
# 66.60% complete
# 66.63% complete
# 66.66% complete
# 66.69% complete
# 66.71% complete
# 66.74% complete
# 66.77% complete
# 66.80% complete
# 66.82% complete
# 66.85% complete
# 66.88% complete
# 66.91% complete
# 66.93% complete
# 66.96% complete
# 66.99% complete
# 67.02% complete
# 67.04% complete
# 67.07% complete
# 67.10% complete
# 67.13% complete
# 67.15% complete
# 67.18% complete
# 67.21% complete
# 67.24% complete
# 67.26% complete
# 67.29% complete
# 67.32% complete
# 67.35% complete
# 67.37% complete
# 67.40% complete
# 67.43% complete
# 67.46% complete
# 67.48% complete
# 67.51% complete
# 67.54% complete
# 67.57% complete
# 67.60% complete
# 67.62% complete
# 67.65% complete
# 67.68% complete
# 67.71% complete
# 67.73% complete
# 67.76% complete
# 67.79% complete
# 67.82% complete
# 67.84% complete
# 67.87% complete
# 67.90% complete
# 67.93% complete
# 67.95% complete
# 67.98% complete
# 68.01% complete
# 68.04% complete
# 68.06% complete
# 68.09% complete
# 68.12% complete
# 68.15% complete
# 68.17% complete
# 68.20% complete
# 68.23% complete
# 68.26% complete
# 68.28% complete
# 68.31% complete
# 68.34% complete
# 68.37% complete
# 68.39% complete
# 68.42% complete
# 68.45% complete
# 68.48% complete
# 68.51% complete
# 68.53% complete
# 68.56% complete
# 68.59% complete
# 68.62% complete
# 68.64% complete
# 68.67% complete
# 68.70% complete
# 68.73% complete
# 68.75% complete
# 68.78% complete
# 68.81% complete
# 68.84% complete
# 68.86% complete
# 68.89% complete
# 68.92% complete
# 68.95% complete
# 68.97% complete
# 69.00% complete
# 69.03% complete
# 69.06% complete
# 69.08% complete
# 69.11% complete
# 69.14% complete
# 69.17% complete
# 69.19% complete
# 69.22% complete
# 69.25% complete
# 69.28% complete
# 69.31% complete
# 69.33% complete
# 69.36% complete
# 69.39% complete
# 69.42% complete
# 69.44% complete
# 69.47% complete
# 69.50% complete
# 69.53% complete
# 69.55% complete
# 69.58% complete
# 69.61% complete
# 69.64% complete
# 69.66% complete
# 69.69% complete
# 69.72% complete
# 69.75% complete
# 69.77% complete
# 69.80% complete
# 69.83% complete
# 69.86% complete
# 69.88% complete
# 69.91% complete
# 69.94% complete
# 69.97% complete
# 69.99% complete
# 70.02% complete
# 70.05% complete
# 70.08% complete
# 70.10% complete
# 70.13% complete
# 70.16% complete
# 70.19% complete
# 70.22% complete
# 70.24% complete
# 70.27% complete
# 70.30% complete
# 70.33% complete
# 70.35% complete
# 70.38% complete
# 70.41% complete
# 70.44% complete
# 70.46% complete
# 70.49% complete
# 70.52% complete
# 70.55% complete
# 70.57% complete
# 70.60% complete
# 70.63% complete
# 70.66% complete
# 70.68% complete
# 70.71% complete
# 70.74% complete
# 70.77% complete
# 70.79% complete
# 70.82% complete
# 70.85% complete
# 70.88% complete
# 70.90% complete
# 70.93% complete
# 70.96% complete
# 70.99% complete
# 71.01% complete
# 71.04% complete
# 71.07% complete
# 71.10% complete
# 71.13% complete
# 71.15% complete
# 71.18% complete
# 71.21% complete
# 71.24% complete
# 71.26% complete
# 71.29% complete
# 71.32% complete
# 71.35% complete
# 71.37% complete
# 71.40% complete
# 71.43% complete
# 71.46% complete
# 71.48% complete
# 71.51% complete
# 71.54% complete
# 71.57% complete
# 71.59% complete
# 71.62% complete
# 71.65% complete
# 71.68% complete
# 71.70% complete
# 71.73% complete
# 71.76% complete
# 71.79% complete
# 71.81% complete
# 71.84% complete
# 71.87% complete
# 71.90% complete
# 71.92% complete
# 71.95% complete
# 71.98% complete
# 72.01% complete
# 72.04% complete
# 72.06% complete
# 72.09% complete
# 72.12% complete
# 72.15% complete
# 72.17% complete
# 72.20% complete
# 72.23% complete
# 72.26% complete
# 72.28% complete
# 72.31% complete
# 72.34% complete
# 72.37% complete
# 72.39% complete
# 72.42% complete
# 72.45% complete
# 72.48% complete
# 72.50% complete
# 72.53% complete
# 72.56% complete
# 72.59% complete
# 72.61% complete
# 72.64% complete
# 72.67% complete
# 72.70% complete
# 72.72% complete
# 72.75% complete
# 72.78% complete
# 72.81% complete
# 72.84% complete
# 72.86% complete
# 72.89% complete
# 72.92% complete
# 72.95% complete
# 72.97% complete
# 73.00% complete
# 73.03% complete
# 73.06% complete
# 73.08% complete
# 73.11% complete
# 73.14% complete
# 73.17% complete
# 73.19% complete
# 73.22% complete
# 73.25% complete
# 73.28% complete
# 73.30% complete
# 73.33% complete
# 73.36% complete
# 73.39% complete
# 73.41% complete
# 73.44% complete
# 73.47% complete
# 73.50% complete
# 73.52% complete
# 73.55% complete
# 73.58% complete
# 73.61% complete
# 73.63% complete
# 73.66% complete
# 73.69% complete
# 73.72% complete
# 73.75% complete
# 73.77% complete
# 73.80% complete
# 73.83% complete
# 73.86% complete
# 73.88% complete
# 73.91% complete
# 73.94% complete
# 73.97% complete
# 73.99% complete
# 74.02% complete
# 74.05% complete
# 74.08% complete
# 74.10% complete
# 74.13% complete
# 74.16% complete
# 74.19% complete
# 74.21% complete
# 74.24% complete
# 74.27% complete
# 74.30% complete
# 74.32% complete
# 74.35% complete
# 74.38% complete
# 74.41% complete
# 74.43% complete
# 74.46% complete
# 74.49% complete
# 74.52% complete
# 74.54% complete
# 74.57% complete
# 74.60% complete
# 74.63% complete
# 74.66% complete
# 74.68% complete
# 74.71% complete
# 74.74% complete
# 74.77% complete
# 74.79% complete
# 74.82% complete
# 74.85% complete
# 74.88% complete
# 74.90% complete
# 74.93% complete
# 74.96% complete
# 74.99% complete
# 75.01% complete
# 75.04% complete
# 75.07% complete
# 75.10% complete
# 75.12% complete
# 75.15% complete
# 75.18% complete
# 75.21% complete
# 75.23% complete
# 75.26% complete
# 75.29% complete
# 75.32% complete
# 75.34% complete
# 75.37% complete
# 75.40% complete
# 75.43% complete
# 75.46% complete
# 75.48% complete
# 75.51% complete
# 75.54% complete
# 75.57% complete
# 75.59% complete
# 75.62% complete
# 75.65% complete
# 75.68% complete
# 75.70% complete
# 75.73% complete
# 75.76% complete
# 75.79% complete
# 75.81% complete
# 75.84% complete
# 75.87% complete
# 75.90% complete
# 75.92% complete
# 75.95% complete
# 75.98% complete
# 76.01% complete
# 76.03% complete
# 76.06% complete
# 76.09% complete
# 76.12% complete
# 76.14% complete
# 76.17% complete
# 76.20% complete
# 76.23% complete
# 76.25% complete
# 76.28% complete
# 76.31% complete
# 76.34% complete
# 76.37% complete
# 76.39% complete
# 76.42% complete
# 76.45% complete
# 76.48% complete
# 76.50% complete
# 76.53% complete
# 76.56% complete
# 76.59% complete
# 76.61% complete
# 76.64% complete
# 76.67% complete
# 76.70% complete
# 76.72% complete
# 76.75% complete
# 76.78% complete
# 76.81% complete
# 76.83% complete
# 76.86% complete
# 76.89% complete
# 76.92% complete
# 76.94% complete
# 76.97% complete
# 77.00% complete
# 77.03% complete
# 77.05% complete
# 77.08% complete
# 77.11% complete
# 77.14% complete
# 77.16% complete
# 77.19% complete
# 77.22% complete
# 77.25% complete
# 77.28% complete
# 77.30% complete
# 77.33% complete
# 77.36% complete
# 77.39% complete
# 77.41% complete
# 77.44% complete
# 77.47% complete
# 77.50% complete
# 77.52% complete
# 77.55% complete
# 77.58% complete
# 77.61% complete
# 77.63% complete
# 77.66% complete
# 77.69% complete
# 77.72% complete
# 77.74% complete
# 77.77% complete
# 77.80% complete
# 77.83% complete
# 77.85% complete
# 77.88% complete
# 77.91% complete
# 77.94% complete
# 77.96% complete
# 77.99% complete
# 78.02% complete
# 78.05% complete
# 78.08% complete
# 78.10% complete
# 78.13% complete
# 78.16% complete
# 78.19% complete
# 78.21% complete
# 78.24% complete
# 78.27% complete
# 78.30% complete
# 78.32% complete
# 78.35% complete
# 78.38% complete
# 78.41% complete
# 78.43% complete
# 78.46% complete
# 78.49% complete
# 78.52% complete
# 78.54% complete
# 78.57% complete
# 78.60% complete
# 78.63% complete
# 78.65% complete
# 78.68% complete
# 78.71% complete
# 78.74% complete
# 78.76% complete
# 78.79% complete
# 78.82% complete
# 78.85% complete
# 78.87% complete
# 78.90% complete
# 78.93% complete
# 78.96% complete
# 78.99% complete
# 79.01% complete
# 79.04% complete
# 79.07% complete
# 79.10% complete
# 79.12% complete
# 79.15% complete
# 79.18% complete
# 79.21% complete
# 79.23% complete
# 79.26% complete
# 79.29% complete
# 79.32% complete
# 79.34% complete
# 79.37% complete
# 79.40% complete
# 79.43% complete
# 79.45% complete
# 79.48% complete
# 79.51% complete
# 79.54% complete
# 79.56% complete
# 79.59% complete
# 79.62% complete
# 79.65% complete
# 79.67% complete
# 79.70% complete
# 79.73% complete
# 79.76% complete
# 79.78% complete
# 79.81% complete
# 79.84% complete
# 79.87% complete
# 79.90% complete
# 79.92% complete
# 79.95% complete
# 79.98% complete
# 80.01% complete
# 80.03% complete
# 80.06% complete
# 80.09% complete
# 80.12% complete
# 80.14% complete
# 80.17% complete
# 80.20% complete
# 80.23% complete
# 80.25% complete
# 80.28% complete
# 80.31% complete
# 80.34% complete
# 80.36% complete
# 80.39% complete
# 80.42% complete
# 80.45% complete
# 80.47% complete
# 80.50% complete
# 80.53% complete
# 80.56% complete
# 80.58% complete
# 80.61% complete
# 80.64% complete
# 80.67% complete
# 80.69% complete
# 80.72% complete
# 80.75% complete
# 80.78% complete
# 80.81% complete
# 80.83% complete
# 80.86% complete
# 80.89% complete
# 80.92% complete
# 80.94% complete
# 80.97% complete
# 81.00% complete
# 81.03% complete
# 81.05% complete
# 81.08% complete
# 81.11% complete
# 81.14% complete
# 81.16% complete
# 81.19% complete
# 81.22% complete
# 81.25% complete
# 81.27% complete
# 81.30% complete
# 81.33% complete
# 81.36% complete
# 81.38% complete
# 81.41% complete
# 81.44% complete
# 81.47% complete
# 81.49% complete
# 81.52% complete
# 81.55% complete
# 81.58% complete
# 81.61% complete
# 81.63% complete
# 81.66% complete
# 81.69% complete
# 81.72% complete
# 81.74% complete
# 81.77% complete
# 81.80% complete
# 81.83% complete
# 81.85% complete
# 81.88% complete
# 81.91% complete
# 81.94% complete
# 81.96% complete
# 81.99% complete
# 82.02% complete
# 82.05% complete
# 82.07% complete
# 82.10% complete
# 82.13% complete
# 82.16% complete
# 82.18% complete
# 82.21% complete
# 82.24% complete
# 82.27% complete
# 82.29% complete
# 82.32% complete
# 82.35% complete
# 82.38% complete
# 82.40% complete
# 82.43% complete
# 82.46% complete
# 82.49% complete
# 82.52% complete
# 82.54% complete
# 82.57% complete
# 82.60% complete
# 82.63% complete
# 82.65% complete
# 82.68% complete
# 82.71% complete
# 82.74% complete
# 82.76% complete
# 82.79% complete
# 82.82% complete
# 82.85% complete
# 82.87% complete
# 82.90% complete
# 82.93% complete
# 82.96% complete
# 82.98% complete
# 83.01% complete
# 83.04% complete
# 83.07% complete
# 83.09% complete
# 83.12% complete
# 83.15% complete
# 83.18% complete
# 83.20% complete
# 83.23% complete
# 83.26% complete
# 83.29% complete
# 83.31% complete
# 83.34% complete
# 83.37% complete
# 83.40% complete
# 83.43% complete
# 83.45% complete
# 83.48% complete
# 83.51% complete
# 83.54% complete
# 83.56% complete
# 83.59% complete
# 83.62% complete
# 83.65% complete
# 83.67% complete
# 83.70% complete
# 83.73% complete
# 83.76% complete
# 83.78% complete
# 83.81% complete
# 83.84% complete
# 83.87% complete
# 83.89% complete
# 83.92% complete
# 83.95% complete
# 83.98% complete
# 84.00% complete
# 84.03% complete
# 84.06% complete
# 84.09% complete
# 84.11% complete
# 84.14% complete
# 84.17% complete
# 84.20% complete
# 84.23% complete
# 84.25% complete
# 84.28% complete
# 84.31% complete
# 84.34% complete
# 84.36% complete
# 84.39% complete
# 84.42% complete
# 84.45% complete
# 84.47% complete
# 84.50% complete
# 84.53% complete
# 84.56% complete
# 84.58% complete
# 84.61% complete
# 84.64% complete
# 84.67% complete
# 84.69% complete
# 84.72% complete
# 84.75% complete
# 84.78% complete
# 84.80% complete
# 84.83% complete
# 84.86% complete
# 84.89% complete
# 84.91% complete
# 84.94% complete
# 84.97% complete
# 85.00% complete
# 85.02% complete
# 85.05% complete
# 85.08% complete
# 85.11% complete
# 85.14% complete
# 85.16% complete
# 85.19% complete
# 85.22% complete
# 85.25% complete
# 85.27% complete
# 85.30% complete
# 85.33% complete
# 85.36% complete
# 85.38% complete
# 85.41% complete
# 85.44% complete
# 85.47% complete
# 85.49% complete
# 85.52% complete
# 85.55% complete
# 85.58% complete
# 85.60% complete
# 85.63% complete
# 85.66% complete
# 85.69% complete
# 85.71% complete
# 85.74% complete
# 85.77% complete
# 85.80% complete
# 85.82% complete
# 85.85% complete
# 85.88% complete
# 85.91% complete
# 85.93% complete
# 85.96% complete
# 85.99% complete
# 86.02% complete
# 86.05% complete
# 86.07% complete
# 86.10% complete
# 86.13% complete
# 86.16% complete
# 86.18% complete
# 86.21% complete
# 86.24% complete
# 86.27% complete
# 86.29% complete
# 86.32% complete
# 86.35% complete
# 86.38% complete
# 86.40% complete
# 86.43% complete
# 86.46% complete
# 86.49% complete
# 86.51% complete
# 86.54% complete
# 86.57% complete
# 86.60% complete
# 86.62% complete
# 86.65% complete
# 86.68% complete
# 86.71% complete
# 86.73% complete
# 86.76% complete
# 86.79% complete
# 86.82% complete
# 86.85% complete
# 86.87% complete
# 86.90% complete
# 86.93% complete
# 86.96% complete
# 86.98% complete
# 87.01% complete
# 87.04% complete
# 87.07% complete
# 87.09% complete
# 87.12% complete
# 87.15% complete
# 87.18% complete
# 87.20% complete
# 87.23% complete
# 87.26% complete
# 87.29% complete
# 87.31% complete
# 87.34% complete
# 87.37% complete
# 87.40% complete
# 87.42% complete
# 87.45% complete
# 87.48% complete
# 87.51% complete
# 87.53% complete
# 87.56% complete
# 87.59% complete
# 87.62% complete
# 87.64% complete
# 87.67% complete
# 87.70% complete
# 87.73% complete
# 87.76% complete
# 87.78% complete
# 87.81% complete
# 87.84% complete
# 87.87% complete
# 87.89% complete
# 87.92% complete
# 87.95% complete
# 87.98% complete
# 88.00% complete
# 88.03% complete
# 88.06% complete
# 88.09% complete
# 88.11% complete
# 88.14% complete
# 88.17% complete
# 88.20% complete
# 88.22% complete
# 88.25% complete
# 88.28% complete
# 88.31% complete
# 88.33% complete
# 88.36% complete
# 88.39% complete
# 88.42% complete
# 88.44% complete
# 88.47% complete
# 88.50% complete
# 88.53% complete
# 88.55% complete
# 88.58% complete
# 88.61% complete
# 88.64% complete
# 88.67% complete
# 88.69% complete
# 88.72% complete
# 88.75% complete
# 88.78% complete
# 88.80% complete
# 88.83% complete
# 88.86% complete
# 88.89% complete
# 88.91% complete
# 88.94% complete
# 88.97% complete
# 89.00% complete
# 89.02% complete
# 89.05% complete
# 89.08% complete
# 89.11% complete
# 89.13% complete
# 89.16% complete
# 89.19% complete
# 89.22% complete
# 89.24% complete
# 89.27% complete
# 89.30% complete
# 89.33% complete
# 89.35% complete
# 89.38% complete
# 89.41% complete
# 89.44% complete
# 89.46% complete
# 89.49% complete
# 89.52% complete
# 89.55% complete
# 89.58% complete
# 89.60% complete
# 89.63% complete
# 89.66% complete
# 89.69% complete
# 89.71% complete
# 89.74% complete
# 89.77% complete
# 89.80% complete
# 89.82% complete
# 89.85% complete
# 89.88% complete
# 89.91% complete
# 89.93% complete
# 89.96% complete
# 89.99% complete
# 90.02% complete
# 90.04% complete
# 90.07% complete
# 90.10% complete
# 90.13% complete
# 90.15% complete
# 90.18% complete
# 90.21% complete
# 90.24% complete
# 90.26% complete
# 90.29% complete
# 90.32% complete
# 90.35% complete
# 90.38% complete
# 90.40% complete
# 90.43% complete
# 90.46% complete
# 90.49% complete
# 90.51% complete
# 90.54% complete
# 90.57% complete
# 90.60% complete
# 90.62% complete
# 90.65% complete
# 90.68% complete
# 90.71% complete
# 90.73% complete
# 90.76% complete
# 90.79% complete
# 90.82% complete
# 90.84% complete
# 90.87% complete
# 90.90% complete
# 90.93% complete
# 90.95% complete
# 90.98% complete
# 91.01% complete
# 91.04% complete
# 91.06% complete
# 91.09% complete
# 91.12% complete
# 91.15% complete
# 91.17% complete
# 91.20% complete
# 91.23% complete
# 91.26% complete
# 91.29% complete
# 91.31% complete
# 91.34% complete
# 91.37% complete
# 91.40% complete
# 91.42% complete
# 91.45% complete
# 91.48% complete
# 91.51% complete
# 91.53% complete
# 91.56% complete
# 91.59% complete
# 91.62% complete
# 91.64% complete
# 91.67% complete
# 91.70% complete
# 91.73% complete
# 91.75% complete
# 91.78% complete
# 91.81% complete
# 91.84% complete
# 91.86% complete
# 91.89% complete
# 91.92% complete
# 91.95% complete
# 91.97% complete
# 92.00% complete
# 92.03% complete
# 92.06% complete
# 92.08% complete
# 92.11% complete
# 92.14% complete
# 92.17% complete
# 92.20% complete
# 92.22% complete
# 92.25% complete
# 92.28% complete
# 92.31% complete
# 92.33% complete
# 92.36% complete
# 92.39% complete
# 92.42% complete
# 92.44% complete
# 92.47% complete
# 92.50% complete
# 92.53% complete
# 92.55% complete
# 92.58% complete
# 92.61% complete
# 92.64% complete
# 92.66% complete
# 92.69% complete
# 92.72% complete
# 92.75% complete
# 92.77% complete
# 92.80% complete
# 92.83% complete
# 92.86% complete
# 92.88% complete
# 92.91% complete
# 92.94% complete
# 92.97% complete
# 93.00% complete
# 93.02% complete
# 93.05% complete
# 93.08% complete
# 93.11% complete
# 93.13% complete
# 93.16% complete
# 93.19% complete
# 93.22% complete
# 93.24% complete
# 93.27% complete
# 93.30% complete
# 93.33% complete
# 93.35% complete
# 93.38% complete
# 93.41% complete
# 93.44% complete
# 93.46% complete
# 93.49% complete
# 93.52% complete
# 93.55% complete
# 93.57% complete
# 93.60% complete
# 93.63% complete
# 93.66% complete
# 93.68% complete
# 93.71% complete
# 93.74% complete
# 93.77% complete
# 93.79% complete
# 93.82% complete
# 93.85% complete
# 93.88% complete
# 93.91% complete
# 93.93% complete
# 93.96% complete
# 93.99% complete
# 94.02% complete
# 94.04% complete
# 94.07% complete
# 94.10% complete
# 94.13% complete
# 94.15% complete
# 94.18% complete
# 94.21% complete
# 94.24% complete
# 94.26% complete
# 94.29% complete
# 94.32% complete
# 94.35% complete
# 94.37% complete
# 94.40% complete
# 94.43% complete
# 94.46% complete
# 94.48% complete
# 94.51% complete
# 94.54% complete
# 94.57% complete
# 94.59% complete
# 94.62% complete
# 94.65% complete
# 94.68% complete
# 94.70% complete
# 94.73% complete
# 94.76% complete
# 94.79% complete
# 94.82% complete
# 94.84% complete
# 94.87% complete
# 94.90% complete
# 94.93% complete
# 94.95% complete
# 94.98% complete
# 95.01% complete
# 95.04% complete
# 95.06% complete
# 95.09% complete
# 95.12% complete
# 95.15% complete
# 95.17% complete
# 95.20% complete
# 95.23% complete
# 95.26% complete
# 95.28% complete
# 95.31% complete
# 95.34% complete
# 95.37% complete
# 95.39% complete
# 95.42% complete
# 95.45% complete
# 95.48% complete
# 95.50% complete
# 95.53% complete
# 95.56% complete
# 95.59% complete
# 95.62% complete
# 95.64% complete
# 95.67% complete
# 95.70% complete
# 95.73% complete
# 95.75% complete
# 95.78% complete
# 95.81% complete
# 95.84% complete
# 95.86% complete
# 95.89% complete
# 95.92% complete
# 95.95% complete
# 95.97% complete
# 96.00% complete
# 96.03% complete
# 96.06% complete
# 96.08% complete
# 96.11% complete
# 96.14% complete
# 96.17% complete
# 96.19% complete
# 96.22% complete
# 96.25% complete
# 96.28% complete
# 96.30% complete
# 96.33% complete
# 96.36% complete
# 96.39% complete
# 96.41% complete
# 96.44% complete
# 96.47% complete
# 96.50% complete
# 96.53% complete
# 96.55% complete
# 96.58% complete
# 96.61% complete
# 96.64% complete
# 96.66% complete
# 96.69% complete
# 96.72% complete
# 96.75% complete
# 96.77% complete
# 96.80% complete
# 96.83% complete
# 96.86% complete
# 96.88% complete
# 96.91% complete
# 96.94% complete
# 96.97% complete
# 96.99% complete
# 97.02% complete
# 97.05% complete
# 97.08% complete
# 97.10% complete
# 97.13% complete
# 97.16% complete
# 97.19% complete
# 97.21% complete
# 97.24% complete
# 97.27% complete
# 97.30% complete
# 97.32% complete
# 97.35% complete
# 97.38% complete
# 97.41% complete
# 97.44% complete
# 97.46% complete
# 97.49% complete
# 97.52% complete
# 97.55% complete
# 97.57% complete
# 97.60% complete
# 97.63% complete
# 97.66% complete
# 97.68% complete
# 97.71% complete
# 97.74% complete
# 97.77% complete
# 97.79% complete
# 97.82% complete
# 97.85% complete
# 97.88% complete
# 97.90% complete
# 97.93% complete
# 97.96% complete
# 97.99% complete
# 98.01% complete
# 98.04% complete
# 98.07% complete
# 98.10% complete
# 98.12% complete
# 98.15% complete
# 98.18% complete
# 98.21% complete
# 98.23% complete
# 98.26% complete
# 98.29% complete
# 98.32% complete
# 98.35% complete
# 98.37% complete
# 98.40% complete
# 98.43% complete
# 98.46% complete
# 98.48% complete
# 98.51% complete
# 98.54% complete
# 98.57% complete
# 98.59% complete
# 98.62% complete
# 98.65% complete
# 98.68% complete
# 98.70% complete
# 98.73% complete
# 98.76% complete
# 98.79% complete
# 98.81% complete
# 98.84% complete
# 98.87% complete
# 98.90% complete
# 98.92% complete
# 98.95% complete
# 98.98% complete
# 99.01% complete
# 99.03% complete
# 99.06% complete
# 99.09% complete
# 99.12% complete
# 99.15% complete
# 99.17% complete
# 99.20% complete
# 99.23% complete
# 99.26% complete
# 99.28% complete
# 99.31% complete
# 99.34% complete
# 99.37% complete
# 99.39% complete
# 99.42% complete
# 99.45% complete
# 99.48% complete
# 99.50% complete
# 99.53% complete
# 99.56% complete
# 99.59% complete
# 99.61% complete
# 99.64% complete
# 99.67% complete
# 99.70% complete
# 99.72% complete
# 99.75% complete
# 99.78% complete
# 99.81% complete
# 99.83% complete
# 99.86% complete
# 99.89% complete
# 99.92% complete
# 99.94% complete
# 99.97% complete
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-495ef11611a3> in <module>
# ----> 1 portfolio = pipeline(200, 20, 5)
#
# <ipython-input-74-bc3b5d32c50d> in pipeline(n, k, num_stocks)
#      11         return_t = portfolio_return(topn, botn, pred_actual)
#      12         t_index = time_range.get_loc(t) + 1
# ---> 13         portfolio['Portfolio Return'].loc[time_range[t_index]] = return_t
#      14
#      15         count +=1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\extension.py in __getitem__(self, key)
#     236
#     237     def __getitem__(self, key):
# --> 238         result = self._data[key]
#     239         if isinstance(result, type(self._data)):
#     240             if result.ndim == 1:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in __getitem__(self, key)
#     279         only handle list-likes, slices, and integer scalars
#     280         """
# --> 281         result = super().__getitem__(key)
#     282         if lib.is_scalar(result):
#     283             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py in __getitem__(self, key)
#     220         if lib.is_integer(key):
#     221             # fast-path
# --> 222             result = self._ndarray[key]
#     223             if self.ndim == 1:
#     224                 return self._box_func(result)
#
# IndexError: index 3626 is out of bounds for axis 0 with size 3626

# %%
#started at 3:07pm
print(pd.datetime.now())

# %%
portfolio

# %%
portfolio.plot()

# %%
import matplotlib.ticker as ticker

fig, axes = plt.subplots(figsize=(30,15))
sns.barplot(x = portfolio.index, y = 'Portfolio Return', data = portfolio, color = 'grey')

axes.xaxis.set_major_locator(mdates.YearLocator())
axes.xaxis.set_minor_locator(mdates.MonthLocator())

ticklabels = [item.strftime('%Y') for item in portfolio.resample('Y').mean().index.to_period('Y')]

axes.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))

plt.xticks(rotation = 'vertical')
axes.set_title('Portfolio Returns')

sns.set(font_scale=2)
plt.axhline(0)

plt.tight_layout()


plt.show()

# %%
ticklabels = [item.strftime('%Y') for item in portfolio.resample('Y').mean().loc['2007':'2021'].index.to_period('Y')]
ticklabels
# Out:
# ['2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
portfolio_monthly = portfolio.resample('M').mean()
portfolio_monthly
# Out:
#             Portfolio Return
# date
# 2007-01-31         -0.242289
# 2007-02-28          0.161326
# 2007-03-31          0.007464
# 2007-04-30          0.078076
# 2007-05-31          0.095436
# ...                      ...
# 2021-01-31         -1.961974
# 2021-02-28         -1.727161
# 2021-03-31         -0.710652
# 2021-04-30          0.468161
# 2021-05-31         -0.448991
#
# [173 rows x 1 columns]

# %%
avg_return = portfolio['Portfolio Return'].mean()
print(f'Average return is {avg_return:.2f} %')
# Out:
# Average return is 0.08 %

# %%
portfolio.to_csv('results/LinearRegression')

# %%
df = pd.read_csv('results/LinearRegression', parse_dates = True, index_col = ['date'])

# %%
df
# Out:
#             Portfolio Return
# date
# 2007-01-03          2.604765
# 2007-01-04          1.298254
# 2007-01-05         -1.549877
# 2007-01-08         -0.627916
# 2007-01-09          0.634558
# ...                      ...
# 2021-05-21          1.494419
# 2021-05-24         -0.306530
# 2021-05-25          4.912235
# 2021-05-26          2.109617
# 2021-05-27         -1.523220
#
# [3626 rows x 1 columns]

# %%
rolling_avg = pd.DataFrame(data = df['Portfolio Return'].rolling(252).mean())

# %%
rolling_avg.dropna(inplace = True)

# %%
rolling_avg
# Out:
#             Portfolio Return
# date
# 2008-01-02          0.246002
# 2008-01-03          0.237357
# 2008-01-04          0.244239
# 2008-01-07          0.263288
# 2008-01-08          0.267650
# ...                      ...
# 2021-05-21         -0.566794
# 2021-05-24         -0.520837
# 2021-05-25         -0.482548
# 2021-05-26         -0.456824
# 2021-05-27         -0.483731
#
# [3375 rows x 1 columns]

# %%
fig, axes = plt.subplots(figsize=(30,15))
sns.barplot(x = df.index, y = 'Portfolio Return', data = df, color = 'grey')

axes.xaxis.set_major_locator(mdates.YearLocator())
axes.xaxis.set_minor_locator(mdates.MonthLocator())

ticklabels = [item.strftime('%Y') for item in portfolio.resample('Y').mean().index.to_period('Y')]

axes.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))

plt.xticks(rotation = 'vertical')
axes.set_title('Portfolio Returns')

sns.set(font_scale=2)
plt.axhline(0)

plt.tight_layout()


plt.show()

# %%
sns.lineplot(x = rolling_avg.index, y = 'Portfolio Return', data = rolling_avg, color = 'black')
plt.xticks(rotation = 'vertical')
# Out:
# (array([13149., 13879., 14610., 15340., 16071., 16801., 17532., 18262.,
#         18993.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
