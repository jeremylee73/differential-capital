# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
prices = pd.read_csv("Data/stock_prices.csv")
prices.head()
# Out:
#          date  905270  921795  904261  905261  916328  923024  936365  902355  \
# 0  1990-01-02   22.75   12.63   30.00   29.61  3.8736   11.00  4.1250   24.50
# 1  1990-01-03   22.56   12.57   31.50   29.37  3.8876   11.00  4.0000   24.50
# 2  1990-01-04   22.38   12.41   32.25   28.89  3.8806   11.38  3.9375   24.63
# 3  1990-01-05   21.81   12.60   32.13   28.41  3.8387   11.50  3.8125   24.75
# 4  1990-01-08   22.25   12.49   32.13   29.13  3.8387   11.50  3.8125   25.00
#
#    912215  ...  9889RL  69568X  543755  77463M  29235J  131745  69487D  \
# 0   58.00  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   57.75  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   57.88  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   57.50  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   57.75  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    68157P  9110RA  292703
# 0     NaN     NaN     NaN
# ...

# %%
tts = train_test_split(prices, test_size=0.2, shuffle=False)
train = tts[0]
test = tts[1]

# %%
train.to_csv("train.csv")

# %%
test.to_csv("test.csv")
