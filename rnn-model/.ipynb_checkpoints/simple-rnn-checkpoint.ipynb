# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
train = pd.read_csv("../Data/train.csv").drop(columns="Unnamed: 0")
test = pd.read_csv("../Data/test.csv").drop(columns="Unnamed: 0")
train
# Out:
#             date  905270  921795  904261  905261   916328  923024  936365  \
# 0     1990-01-02   22.75   12.63   30.00   29.61   3.8736   11.00  4.1250
# 1     1990-01-03   22.56   12.57   31.50   29.37   3.8876   11.00  4.0000
# 2     1990-01-04   22.38   12.41   32.25   28.89   3.8806   11.38  3.9375
# 3     1990-01-05   21.81   12.60   32.13   28.41   3.8387   11.50  3.8125
# 4     1990-01-08   22.25   12.49   32.13   29.13   3.8387   11.50  3.8125
# ...          ...     ...     ...     ...     ...      ...     ...     ...
# 6326  2015-02-09   53.81   11.39   29.69   20.35  44.5200   30.00  3.0400
# 6327  2015-02-10   53.81   11.39   29.69   20.35  44.9200   30.00  3.0400
# 6328  2015-02-11   53.81   11.39   29.69   20.35  44.9300   30.00  3.0700
# 6329  2015-02-12   53.81   11.39   29.69   20.35  45.2200   30.00  3.1200
# 6330  2015-02-13   53.81   11.39   29.69   20.35  46.0900   30.00  3.1500
#
#       902355  912215  ...  9889RL  69568X  543755  77463M  29235J  131745  \
# 0      24.50   58.00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1      24.50   57.75  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2      24.63   57.88  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3      24.75   57.50  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4      25.00   57.75  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 6326   57.94   68.13  ...     NaN  43.496  26.490   14.47   47.37   16.20
# 6327   57.94   68.13  ...     NaN  43.258  26.350   14.46   49.10   16.50
# 6328   57.94   68.13  ...     NaN  42.560  26.420   14.79   49.51   16.69
# 6329   57.94   68.13  ...     NaN  40.576  27.260   14.78   50.16   16.83
# 6330   57.94   68.13  ...     NaN  40.754  26.865   15.15   50.32   16.62
#
#       69487D  68157P  9110RA  292703
# 0        NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...
# 6326   80.97   46.78   4.180   68.80
# 6327   81.96   47.61   4.158   69.70
# 6328   83.86   48.94   4.160   73.14
# 6329   85.39   49.60   4.190   73.94
# 6330   84.79   49.89   4.200   73.61
#
# [6331 rows x 1242 columns]

# %%
train["date"] = pd.to_datetime(train["date"], format="%Y-%m-%d")
test["date"] = pd.to_datetime(test["date"], format="%Y-%m-%d")

# %%
# Looking at sample stock
sample = train[["916328"]]
sample
# Out:
#        916328
# 0      3.8736
# 1      3.8876
# 2      3.8806
# 3      3.8387
# 4      3.8387
# ...       ...
# 6326  44.5200
# 6327  44.9200
# 6328  44.9300
# 6329  45.2200
# 6330  46.0900
#
# [6331 rows x 1 columns]

# %%
step = 4
# add step elements into sample
sample = np.append(sample, np.repeat(sample.iloc[-1,], step))

# %%
# convert into dataset matrix
def convertToMatrix(data, step):
    X, Y = [], []
    for i in range(len(data) - step):
        d = i + step
        X.append(data[i:d, ])
        Y.append(data[d,])
    return np.array(X), np.array(Y)

sampleX, sampleY = convertToMatrix(sample, step)

# %%
sampleX
# Out:
# array([[ 3.8736,  3.8876,  3.8806,  3.8387],
#        [ 3.8876,  3.8806,  3.8387,  3.8387],
#        [ 3.8806,  3.8387,  3.8387,  3.8247],
#        ...,
#        [44.93  , 45.22  , 46.09  , 46.09  ],
#        [45.22  , 46.09  , 46.09  , 46.09  ],
#        [46.09  , 46.09  , 46.09  , 46.09  ]])

# %%
sampleY
# Out:
# array([ 3.8387,  3.8247,  3.7757, ..., 46.09  , 46.09  , 46.09  ])

# %%
# reshaping to 3d for inputting into Keras model
sampleX = np.reshape(sampleX, (sampleX.shape[0], 1, sampleX.shape[1]))
sampleX.shape
# Out:
# (6331, 1, 4)

# %%
# building SimpleRNN model
model = Sequential()
model.add(SimpleRNN(units=32, input_shape=(1, step), activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="rmsprop")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 32)                1184
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,457
# Trainable params: 1,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sampleX, sampleY, epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 396/396 - 1s - loss: 33.7231
# Epoch 2/100
# 396/396 - 0s - loss: 0.1770
# Epoch 3/100
# 396/396 - 0s - loss: 0.1698
# Epoch 4/100
# 396/396 - 0s - loss: 0.1675
# Epoch 5/100
# 396/396 - 0s - loss: 0.1647
# Epoch 6/100
# 396/396 - 1s - loss: 0.1618
# Epoch 7/100
# 396/396 - 0s - loss: 0.1618
# Epoch 8/100
# 396/396 - 0s - loss: 0.1582
# Epoch 9/100
# 396/396 - 0s - loss: 0.1594
# Epoch 10/100
# 396/396 - 0s - loss: 0.1547
# Epoch 11/100
# 396/396 - 0s - loss: 0.1562
# Epoch 12/100
# 396/396 - 0s - loss: 0.1554
# Epoch 13/100
# 396/396 - 0s - loss: 0.1548
# Epoch 14/100
# 396/396 - 0s - loss: 0.1499
# Epoch 15/100
# 396/396 - 1s - loss: 0.1522
# Epoch 16/100
# 396/396 - 0s - loss: 0.1506
# Epoch 17/100
# 396/396 - 0s - loss: 0.1500
# Epoch 18/100
# 396/396 - 0s - loss: 0.1512
# Epoch 19/100
# 396/396 - 0s - loss: 0.1505
# Epoch 20/100
# 396/396 - 0s - loss: 0.1497
# Epoch 21/100
# 396/396 - 0s - loss: 0.1510
# Epoch 22/100
# 396/396 - 0s - loss: 0.1455
# Epoch 23/100
# 396/396 - 0s - loss: 0.1452
# Epoch 24/100
# 396/396 - 0s - loss: 0.1447
# Epoch 25/100
# 396/396 - 0s - loss: 0.1422
# Epoch 26/100
# 396/396 - 1s - loss: 0.1437
# Epoch 27/100
# 396/396 - 0s - loss: 0.1432
# Epoch 28/100
# 396/396 - 0s - loss: 0.1440
# Epoch 29/100
# 396/396 - 0s - loss: 0.1430
# Epoch 30/100
# 396/396 - 0s - loss: 0.1433
# Epoch 31/100
# 396/396 - 0s - loss: 0.1452
# Epoch 32/100
# 396/396 - 0s - loss: 0.1427
# Epoch 33/100
# 396/396 - 0s - loss: 0.1405
# Epoch 34/100
# 396/396 - 0s - loss: 0.1411
# Epoch 35/100
# 396/396 - 0s - loss: 0.1406
# Epoch 36/100
# 396/396 - 0s - loss: 0.1391
# Epoch 37/100
# 396/396 - 0s - loss: 0.1403
# Epoch 38/100
# 396/396 - 0s - loss: 0.1395
# Epoch 39/100
# 396/396 - 0s - loss: 0.1390
# Epoch 40/100
# 396/396 - 0s - loss: 0.1388
# Epoch 41/100
# 396/396 - 0s - loss: 0.1350
# Epoch 42/100
# 396/396 - 0s - loss: 0.1374
# Epoch 43/100
# 396/396 - 0s - loss: 0.1382
# Epoch 44/100
# 396/396 - 0s - loss: 0.1374
# Epoch 45/100
# 396/396 - 0s - loss: 0.1361
# Epoch 46/100
# 396/396 - 0s - loss: 0.1362
# Epoch 47/100
# 396/396 - 0s - loss: 0.1344
# Epoch 48/100
# 396/396 - 0s - loss: 0.1344
# Epoch 49/100
# 396/396 - 0s - loss: 0.1355
# Epoch 50/100
# 396/396 - 0s - loss: 0.1348
# Epoch 51/100
# 396/396 - 0s - loss: 0.1343
# Epoch 52/100
# 396/396 - 0s - loss: 0.1355
# Epoch 53/100
# 396/396 - 0s - loss: 0.1331
# Epoch 54/100
# 396/396 - 0s - loss: 0.1322
# Epoch 55/100
# 396/396 - 0s - loss: 0.1330
# Epoch 56/100
# 396/396 - 0s - loss: 0.1299
# Epoch 57/100
# 396/396 - 1s - loss: 0.1346
# Epoch 58/100
# 396/396 - 1s - loss: 0.1316
# Epoch 59/100
# 396/396 - 0s - loss: 0.1320
# Epoch 60/100
# 396/396 - 1s - loss: 0.1314
# Epoch 61/100
# 396/396 - 0s - loss: 0.1300
# Epoch 62/100
# 396/396 - 1s - loss: 0.1289
# Epoch 63/100
# 396/396 - 0s - loss: 0.1300
# Epoch 64/100
# 396/396 - 0s - loss: 0.1318
# Epoch 65/100
# 396/396 - 0s - loss: 0.1285
# Epoch 66/100
# 396/396 - 0s - loss: 0.1303
# Epoch 67/100
# 396/396 - 0s - loss: 0.1290
# Epoch 68/100
# 396/396 - 0s - loss: 0.1299
# Epoch 69/100
# 396/396 - 0s - loss: 0.1286
# Epoch 70/100
# 396/396 - 0s - loss: 0.1287
# Epoch 71/100
# 396/396 - 0s - loss: 0.1270
# Epoch 72/100
# 396/396 - 1s - loss: 0.1277
# Epoch 73/100
# 396/396 - 0s - loss: 0.1283
# Epoch 74/100
# 396/396 - 0s - loss: 0.1276
# Epoch 75/100
# 396/396 - 0s - loss: 0.1277
# Epoch 76/100
# 396/396 - 0s - loss: 0.1281
# Epoch 77/100
# 396/396 - 0s - loss: 0.1269
# Epoch 78/100
# 396/396 - 0s - loss: 0.1258
# Epoch 79/100
# 396/396 - 0s - loss: 0.1246
# Epoch 80/100
# 396/396 - 0s - loss: 0.1242
# Epoch 81/100
# 396/396 - 0s - loss: 0.1258
# Epoch 82/100
# 396/396 - 0s - loss: 0.1228
# Epoch 83/100
# 396/396 - 0s - loss: 0.1249
# Epoch 84/100
# 396/396 - 0s - loss: 0.1244
# Epoch 85/100
# 396/396 - 0s - loss: 0.1248
# Epoch 86/100
# 396/396 - 0s - loss: 0.1239
# Epoch 87/100
# 396/396 - 1s - loss: 0.1246
# Epoch 88/100
# 396/396 - 1s - loss: 0.1243
# Epoch 89/100
# 396/396 - 0s - loss: 0.1241
# Epoch 90/100
# 396/396 - 0s - loss: 0.1251
# Epoch 91/100
# 396/396 - 0s - loss: 0.1233
# Epoch 92/100
# 396/396 - 0s - loss: 0.1237
# Epoch 93/100
# 396/396 - 0s - loss: 0.1254
# Epoch 94/100
# 396/396 - 0s - loss: 0.1228
# Epoch 95/100
# 396/396 - 0s - loss: 0.1245
# Epoch 96/100
# 396/396 - 0s - loss: 0.1227
# Epoch 97/100
# 396/396 - 0s - loss: 0.1241
# Epoch 98/100
# 396/396 - 0s - loss: 0.1221
# Epoch 99/100
# 396/396 - 0s - loss: 0.1248
# Epoch 100/100
# 396/396 - 0s - loss: 0.1205

# %%
pred_sample = model.predict(sampleX)
sns.regplot(x=sampleY, y=pred_sample)

# %%
df = pd.DataFrame()
df["sampleY"] = sampleY
df["pred_sample"] = pred_sample
df = df.iloc[:-4,]
df["date"] = train["date"].iloc[4:].reset_index(drop=True)
df
# Out:
#       sampleY  pred_sample       date
# 0      3.8387     3.863085 1990-01-08
# 1      3.8247     3.855812 1990-01-09
# 2      3.7757     3.845501 1990-01-10
# 3      3.8107     3.801773 1990-01-11
# 4      3.7338     3.821322 1990-01-12
# ...       ...          ...        ...
# 6322  44.5200    45.642754 2015-02-09
# 6323  44.9200    44.783875 2015-02-10
# 6324  44.9300    44.940224 2015-02-11
# 6325  45.2200    45.051430 2015-02-12
# 6326  46.0900    45.240982 2015-02-13
#
# [6327 rows x 3 columns]

# %%
sns.lineplot(data=df, x="date", y="sampleY")
sns.lineplot(data=df, x="date", y="pred_sample")

# %%
test_out = test[["916328"]]
test_out = np.append(test_out, np.repeat(test_out.iloc[-1,], step))

# %%
testX, testY = convertToMatrix(test_out, step)
testX
# Out:
# array([[ 46.41,  46.41,  46.61,  47.48],
#        [ 46.41,  46.61,  47.48,  47.32],
#        [ 46.61,  47.48,  47.32,  47.47],
#        ...,
#        [116.75, 115.69, 116.65, 116.65],
#        [115.69, 116.65, 116.65, 116.65],
#        [116.65, 116.65, 116.65, 116.65]])

# %%
# reshaping to 3d for inputting into Keras model
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
testX.shape
# Out:
# (1583, 1, 4)

# %%
pred_test = model.predict(testX)
pred_test
# Out:
# array([[ 47.404854],
#        [ 47.43879 ],
#        [ 47.506203],
#        ...,
#        [116.90739 ],
#        [116.83738 ],
#        [116.871506]], dtype=float32)

# %%
df = pd.DataFrame()
df["testY"] = testY
df["pred_test"] = pred_test
df = df.iloc[:-4,]
df["date"] = test["date"].iloc[4:].reset_index(drop=True)
df
# Out:
#        testY   pred_test       date
# 0      47.32   47.404854 2015-02-23
# 1      47.47   47.438789 2015-02-24
# 2      47.40   47.506203 2015-02-25
# 3      47.61   47.515381 2015-02-26
# 4      47.37   47.660084 2015-02-27
# ...      ...         ...        ...
# 1574  117.29  117.501282 2021-05-24
# 1575  118.40  117.431976 2021-05-25
# 1576  116.75  118.429878 2021-05-26
# 1577  115.69  117.283669 2021-05-27
# 1578  116.65  116.081909 2021-05-28
#
# [1579 rows x 3 columns]

# %%
sns.lineplot(data=df, x="date", y="testY")
sns.lineplot(data=df, x="date", y="pred_test")

# %%
# Model metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE: " + str(mean_absolute_error(y_true=df.testY, y_pred=df.pred_test)))
print("MSE: " + str(mean_squared_error(y_true=df.testY, y_pred=df.pred_test)))
print("R2: " + str(r2_score(y_true=df.testY, y_pred=df.pred_test)))
# Out:
# MAE: 0.7338987601475296
# MSE: 1.3034389961364161
# R2: 0.9978198146956455

# %%
model.predict([[[116.66503, 116.722115, 116.678474, 116.70525]]])[0, 0]
# Out:
# 116.91966

# %%
df = pd.DataFrame(columns=["date", "predicted"])
df
# Out:
# Empty DataFrame
# Columns: [date, predicted]
# Index: []

# %%
def predict_price(model, days, last_prices, predictions):
    if days == 0:
        return predictions
    prediction = model.predict([[last_prices]])[0, 0]
    last_prices.append(prediction)
    last_prices = last_prices[1:]
    predictions = predictions.append(pd.DataFrame({"date": [days], "predicted": [prediction]}))
    return predict_price(model, days - 1, last_prices, predictions)

# %%
actual_df = pd.DataFrame(columns=["day", "predicted"])
last_prices = [118.40, 116.75, 115.69, 116.65]
days = 30

for day in range(1, days + 1):
    reshaped = np.array([last_prices])
    reshaped = np.reshape(reshaped, (reshaped.shape[0], 1, reshaped.shape[1]))
    prediction = pred(reshaped)
    last_prices.append(prediction)
    last_prices = last_prices[1:]
    actual_df = actual_df.append(pd.DataFrame({"day": [day], "predicted": [prediction]}))
    
actual_df.set_index("day", inplace=True)
actual_df
# Out:
#       predicted
# day
# 1    116.743370
# 2    116.982582
# 3    117.123337
# 4    117.314255
# 5    117.490646
# 6    117.673630
# 7    117.853882
# 8    118.035507
# 9    118.216972
# 10   118.398888
# 11   118.580986
# 12   118.763382
# 13   118.946053
# 14   119.128967
# 15   119.312164
# 16   119.495621
# 17   119.679352
# 18   119.863342
# 19   120.047607
# 20   120.232170
# 21   120.416985
# 22   120.602058
# 23   120.787422
# 24   120.973038
# 25   121.158943
# 26   121.345108
# 27   121.531563
# 28   121.718277
# 29   121.905258
# 30   122.092522

# %%
sns.lineplot(data=actual_df, x="day", y="predicted")
